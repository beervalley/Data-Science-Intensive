# %%
import pandas as pd
import numpy as np
import matplotlib as plot

# %matplotlib inline

# %%
data = pd.read_csv('market_train.csv')
data.head()
# Out:
# /Users/mingmingguo/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (8,9,10,11,12,43,157,196,214,225,228,229,231,235,238) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#    ID VAR_0001  VAR_0002  VAR_0003  VAR_0004 VAR_0005  VAR_0006  VAR_0007  \
# 0   2        H       224         0      4300        C         0         0
# 1   4        H         7        53      4448        B         1         0
# 2   5        H       116         3      3464        C         0         0
# 3   7        H       240       300      3200        C         0         0
# 4   8        R        72       261      2000        N         0         0
#
#   VAR_0008 VAR_0009   ...   VAR_1926 VAR_1927 VAR_1928   VAR_1929  VAR_1930  \
# 0    False    False   ...         98       98      998  999999998       998
# 1    False    False   ...         98       98      998  999999998       998
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145231 entries, 0 to 145230
# Columns: 1934 entries, ID to target
# dtypes: float64(477), int64(1406), object(51)
# memory usage: 2.1+ GB

# %%
data.tail()
# Out:
#             ID VAR_0001  VAR_0002  VAR_0003  VAR_0004 VAR_0005  VAR_0006  \
# 145226  290457        H       276       144      3000        C         2
# 145227  290458        R        39       414      2821        C         3
# 145228  290459        R       103        31      2604        B         1
# 145229  290461        H        78        12      4325        C         0
# 145230  290463        H       228       120     18500        B         0
#
#         VAR_0007 VAR_0008 VAR_0009   ...   VAR_1926 VAR_1927 VAR_1928  \
# 145226         3    False    False   ...         98       98      998
# 145227         1    False    False   ...         98       98      998
# 145228         1    False    False   ...         98       98      998
# 145229         0    False    False   ...         98       98      998
# 145230         0    False    False   ...         98       98      998
#
#          VAR_1929  VAR_1930  VAR_1931  VAR_1932  VAR_1933  VAR_1934  target
# ...

# %%
data.describe()
# Out:
#                   ID       VAR_0002       VAR_0003        VAR_0004  \
# count  145231.000000  145231.000000  145231.000000   145231.000000
# mean   145124.981808     105.278040      88.492285     3721.946210
# std     83890.290627     143.351237     125.903323    12280.012213
# min         2.000000       0.000000       0.000000        0.000000
# 25%     72342.500000      24.000000      13.000000     1790.000000
# 50%    145272.000000      60.000000      55.000000     2500.000000
# 75%    217686.500000     132.000000     120.000000     3600.000000
# max    290463.000000     999.000000     999.000000  2200000.000000
#
#             VAR_0006      VAR_0007       VAR_0013       VAR_0014  \
# count  145175.000000  145175.00000  145175.000000  145175.000000
# mean        0.693907       0.51316       0.693907       0.494493
# std         1.604578       1.17531       1.604578       1.115085
# min         0.000000       0.00000       0.000000       0.000000
# ...
