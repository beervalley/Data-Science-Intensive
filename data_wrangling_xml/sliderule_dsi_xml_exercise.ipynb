# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )

# %%
# print names of all countries
for child in document_tree.getroot():
    print child.find('name').text
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print '* ' + element.find('name').text + ':',
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print capitals_string[:-2]
# Out:
# * Albania: Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece: Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia: Skopje, Kumanovo
# * Serbia: Beograd, Novi Sad, Niš
# * Montenegro: Podgorica
# * Kosovo: Prishtine
# * Andorra: Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
from xml.etree import ElementTree as ET
document_tree = ET.parse( './data/mondial_database.xml' )

# %%
list_country = []
for country in document_tree.iterfind('country'):
    if country.find('infant_mortality') == None:
        continue
    list_country.append([country.find('name').text , country.find('infant_mortality').text])

# %%
list_country
# Out:
# [['Albania', '13.19'],
#  ['Greece', '4.78'],
#  ['Macedonia', '7.9'],
#  ['Serbia', '6.16'],
#  ['Andorra', '3.69'],
#  ['France', '3.31'],
#  ['Spain', '3.33'],
#  ['Austria', '4.16'],
#  ['Czech Republic', '2.63'],
#  ['Germany', '3.46'],
#  ['Hungary', '5.09'],
#  ['Italy', '3.31'],
#  ['Liechtenstein', '4.33'],
#  ['Slovakia', '5.35'],
#  ['Slovenia', '4.04'],
#  ['Switzerland', '3.73'],
#  ['Belarus', '3.64'],
#  ['Latvia', '7.91'],
#  ['Lithuania', '6'],
#  ['Poland', '6.19'],
#  ['Ukraine', '8.1'],
#  ['Russia', '7.08'],
#  ['Belgium', '4.18'],
#  ['Luxembourg', '4.28'],
#  ['Netherlands', '3.66'],
#  ['Bosnia and Herzegovina', '5.84'],
#  ['Croatia', '5.87'],
#  ['Bulgaria', '15.08'],
#  ['Romania', '10.16'],
#  ['Turkey', '21.43'],
#  ['Denmark', '4.1'],
#  ['Estonia', '6.7'],
#  ['Faroe Islands', '5.71'],
#  ['Finland', '3.36'],
#  ['Norway', '2.48'],
#  ['Sweden', '2.6'],
#  ['Monaco', '1.81'],
#  ['Gibraltar', '6.29'],
#  ['Guernsey', '3.47'],
#  ['Iceland', '3.15'],
#  ['Ireland', '3.74'],
#  ['San Marino', '4.52'],
#  ['Jersey', '3.86'],
#  ['Malta', '3.59'],
#  ['Isle of Man', '4.17'],
#  ['Moldova', '12.93'],
#  ['Portugal', '4.48'],
#  ['United Kingdom', '4.44'],
#  ['Afghanistan', '117.23'],
#  ['China', '14.79'],
#  ['Iran', '39'],
#  ['Pakistan', '57.48'],
#  ['Tajikistan', '35.03'],
#  ['Turkmenistan', '38.13'],
#  ['Uzbekistan', '19.84'],
#  ['Armenia', '13.97'],
#  ['Georgia', '16.68'],
#  ['Azerbaijan', '26.67'],
#  ['Bahrain', '9.68'],
#  ['Bangladesh', '45.67'],
#  ['Myanmar', '44.91'],
#  ['India', '43.19'],
#  ['Bhutan', '37.89'],
#  ['Brunei', '10.48'],
#  ['Malaysia', '13.69'],
#  ['Laos', '54.53'],
#  ['Thailand', '9.86'],
#  ['Cambodia', '51.36'],
#  ['Vietnam', '18.99'],
#  ['Kazakhstan', '21.61'],
#  ['North Korea', '24.5'],
#  ['Kyrgyzstan', '28.71'],
#  ['Hong Kong', '2.73'],
#  ['Macao', '3.13'],
#  ['Mongolia', '23.15'],
#  ['Nepal', '40.43'],
#  ['Cyprus', '8.54'],
#  ['Gaza Strip', '30.6'],
#  ['Israel', '3.98'],
#  ['Egypt', '22.41'],
#  ['Indonesia', '25.16'],
#  ['Timor-Leste', '38.79'],
#  ['Papua New Guinea', '39.67'],
#  ['Iraq', '37.53'],
#  ['Jordan', '15.73'],
#  ['Kuwait', '7.51'],
#  ['Saudi Arabia', '14.58'],
#  ['Syria', '15.79'],
#  ['Lebanon', '7.98'],
#  ['West Bank', '28.6'],
#  ['Japan', '2.13'],
#  ['South Korea', '3.93'],
#  ['Maldives', '24.59'],
#  ['Oman', '14'],
#  ['United Arab Emirates', '10.92'],
#  ['Yemen', '50.41'],
#  ['Philippines', '17.64'],
#  ['Qatar', '6.42'],
#  ['Singapore', '2.53'],
#  ['Sri Lanka', '9.02'],
#  ['Taiwan', '4.49'],
#  ['Anguilla', '3.4'],
#  ['Antigua and Barbuda', '13.29'],
#  ['Aruba', '11.74'],
#  ['Bahamas', '12.5'],
#  ['Barbados', '10.93'],
#  ['Belize', '20.31'],
#  ['Guatemala', '23.51'],
#  ['Mexico', '12.58'],
#  ['Bermuda', '2.48'],
#  ['British Virgin Islands', '13.45'],
#  ['Canada', '4.71'],
#  ['United States', '6.17'],
#  ['Cayman Islands', '6.21'],
#  ['Costa Rica', '8.7'],
#  ['Nicaragua', '20.36'],
#  ['Panama', '10.7'],
#  ['Cuba', '4.7'],
#  ['Dominica', '11.61'],
#  ['Dominican Republic', '19.63'],
#  ['Haiti', '49.43'],
#  ['El Salvador', '18.44'],
#  ['Honduras', '18.72'],
#  ['Greenland', '9.42'],
#  ['Grenada', '10.5'],
#  ['Guadeloupe', '8.3'],
#  ['Jamaica', '13.69'],
#  ['Martinique', '7.1'],
#  ['Montserrat', '13.66'],
#  ['Sint Maarten', '9.05'],
#  ['Colombia', '15.02'],
#  ['Puerto Rico', '7.73'],
#  ['Saint Kitts and Nevis', '8.98'],
#  ['Saint Lucia', '11.75'],
#  ['Saint Pierre and Miquelon', '6.95'],
#  ['Saint Vincent and the Grenadines', '13.07'],
#  ['Trinidad and Tobago', '24.82'],
#  ['Turks and Caicos Islands', '10.97'],
#  ['Virgin Islands', '6.79'],
#  ['American Samoa', '8.92'],
#  ['Australia', '4.43'],
#  ['Cook Islands', '14.33'],
#  ['Fiji', '10.2'],
#  ['French Polynesia', '4.78'],
#  ['Guam', '5.51'],
#  ['Kiribati', '35.37'],
#  ['Marshall Islands', '21.39'],
#  ['Micronesia', '21.93'],
#  ['Nauru', '8.21'],
#  ['New Caledonia', '5.46'],
#  ['New Zealand', '4.59'],
#  ['Northern Mariana Islands', '5.5'],
#  ['Palau', '11.46'],
#  ['Solomon Islands', '16.17'],
#  ['Tonga', '12.36'],
#  ['Tuvalu', '31.69'],
#  ['Vanuatu', '16.41'],
#  ['Wallis and Futuna', '4.49'],
#  ['Samoa', '20.5'],
#  ['Argentina', '9.96'],
#  ['Bolivia', '38.61'],
#  ['Brazil', '19.21'],
#  ['Chile', '7.02'],
#  ['Paraguay', '20.75'],
#  ['Uruguay', '8.97'],
#  ['Peru', '20.21'],
#  ['French Guiana', '14.6'],
#  ['Guyana', '33.56'],
#  ['Suriname', '27.07'],
#  ['Venezuela', '19.33'],
#  ['Ecuador', '17.93'],
#  ['Algeria', '21.76'],
#  ['Libya', '11.87'],
#  ['Mali', '104.34'],
#  ['Mauritania', '56.06'],
#  ['Morocco', '24.52'],
#  ['Niger', '86.27'],
#  ['Tunisia', '23.19'],
#  ['Western Sahara', '145.82'],
#  ['Angola', '79.99'],
#  ['Congo', '59.34'],
#  ['Namibia', '45.64'],
#  ['Zaire', '73.15'],
#  ['Zambia', '66.62'],
#  ['Benin', '57.09'],
#  ['Burkina Faso', '76.8'],
#  ['Nigeria', '74.09'],
#  ['Togo', '46.73'],
#  ['Botswana', '9.38'],
#  ['South Africa', '41.61'],
#  ['Zimbabwe', '26.55'],
#  ['Cote dIvoire', '60.16'],
#  ['Ghana', '38.52'],
#  ['Burundi', '63.44'],
#  ['Rwanda', '59.59'],
#  ['Tanzania', '43.74'],
#  ['Cameroon', '55.1'],
#  ['Central African Republic', '92.86'],
#  ['Chad', '90.3'],
#  ['Equatorial Guinea', '71.12'],
#  ['Gabon', '47.03'],
#  ['Cape Verde', '24.28'],
#  ['Sudan', '52.86'],
#  ['South Sudan', '68.16'],
#  ['Comoros', '65.31'],
#  ['Guinea', '55.24'],
#  ['Liberia', '69.19'],
#  ['Djibouti', '50.2'],
#  ['Eritrea', '38.44'],
#  ['Ethiopia', '55.77'],
#  ['Somalia', '100.14'],
#  ['Kenya', '40.71'],
#  ['Gambia', '65.74'],
#  ['Senegal', '52.72'],
#  ['Guinea-Bissau', '90.92'],
#  ['Sierra Leone', '73.29'],
#  ['Uganda', '60.82'],
#  ['Lesotho', '50.48'],
#  ['Madagascar', '44.88'],
#  ['Malawi', '48.01'],
#  ['Mozambique', '72.42'],
#  ['Mauritius', '10.59'],
#  ['Mayotte', '56.29'],
#  ['Swaziland', '54.82'],
#  ['Reunion', '7.5'],
#  ['Saint Helena', '17.63'],
#  ['Sao Tome and Principe', '49.16'],
#  ['Seychelles', '10.77']]

# %%
import pandas as pd
df = pd.DataFrame(list_country)
df.columns = ['country', 'infant_mortality_rates']
df
# Out:
#                     country infant_mortality_rates
# 0                   Albania                  13.19
# 1                    Greece                   4.78
# 2                 Macedonia                    7.9
# 3                    Serbia                   6.16
# 4                   Andorra                   3.69
# 5                    France                   3.31
# 6                     Spain                   3.33
# 7                   Austria                   4.16
# 8            Czech Republic                   2.63
# 9                   Germany                   3.46
# 10                  Hungary                   5.09
# 11                    Italy                   3.31
# 12            Liechtenstein                   4.33
# 13                 Slovakia                   5.35
# 14                 Slovenia                   4.04
# 15              Switzerland                   3.73
# 16                  Belarus                   3.64
# 17                   Latvia                   7.91
# 18                Lithuania                      6
# 19                   Poland                   6.19
# 20                  Ukraine                    8.1
# 21                   Russia                   7.08
# 22                  Belgium                   4.18
# 23               Luxembourg                   4.28
# 24              Netherlands                   3.66
# 25   Bosnia and Herzegovina                   5.84
# 26                  Croatia                   5.87
# 27                 Bulgaria                  15.08
# 28                  Romania                  10.16
# 29                   Turkey                  21.43
# ..                      ...                    ...
# 198                    Chad                   90.3
# 199       Equatorial Guinea                  71.12
# 200                   Gabon                  47.03
# 201              Cape Verde                  24.28
# 202                   Sudan                  52.86
# 203             South Sudan                  68.16
# 204                 Comoros                  65.31
# 205                  Guinea                  55.24
# 206                 Liberia                  69.19
# 207                Djibouti                   50.2
# 208                 Eritrea                  38.44
# 209                Ethiopia                  55.77
# 210                 Somalia                 100.14
# 211                   Kenya                  40.71
# 212                  Gambia                  65.74
# 213                 Senegal                  52.72
# 214           Guinea-Bissau                  90.92
# 215            Sierra Leone                  73.29
# 216                  Uganda                  60.82
# 217                 Lesotho                  50.48
# 218              Madagascar                  44.88
# 219                  Malawi                  48.01
# 220              Mozambique                  72.42
# 221               Mauritius                  10.59
# 222                 Mayotte                  56.29
# 223               Swaziland                  54.82
# 224                 Reunion                    7.5
# 225            Saint Helena                  17.63
# 226   Sao Tome and Principe                  49.16
# 227              Seychelles                  10.77
#
# [228 rows x 2 columns]

# %%
df.infant_mortality_rates = df.infant_mortality_rates.astype(float)
df
# Out:
#                     country  infant_mortality_rates
# 0                   Albania                   13.19
# 1                    Greece                    4.78
# 2                 Macedonia                    7.90
# 3                    Serbia                    6.16
# 4                   Andorra                    3.69
# 5                    France                    3.31
# 6                     Spain                    3.33
# 7                   Austria                    4.16
# 8            Czech Republic                    2.63
# 9                   Germany                    3.46
# 10                  Hungary                    5.09
# 11                    Italy                    3.31
# 12            Liechtenstein                    4.33
# 13                 Slovakia                    5.35
# 14                 Slovenia                    4.04
# 15              Switzerland                    3.73
# 16                  Belarus                    3.64
# 17                   Latvia                    7.91
# 18                Lithuania                    6.00
# 19                   Poland                    6.19
# 20                  Ukraine                    8.10
# 21                   Russia                    7.08
# 22                  Belgium                    4.18
# 23               Luxembourg                    4.28
# 24              Netherlands                    3.66
# 25   Bosnia and Herzegovina                    5.84
# 26                  Croatia                    5.87
# 27                 Bulgaria                   15.08
# 28                  Romania                   10.16
# 29                   Turkey                   21.43
# ..                      ...                     ...
# 198                    Chad                   90.30
# 199       Equatorial Guinea                   71.12
# 200                   Gabon                   47.03
# 201              Cape Verde                   24.28
# 202                   Sudan                   52.86
# 203             South Sudan                   68.16
# 204                 Comoros                   65.31
# 205                  Guinea                   55.24
# 206                 Liberia                   69.19
# 207                Djibouti                   50.20
# 208                 Eritrea                   38.44
# 209                Ethiopia                   55.77
# 210                 Somalia                  100.14
# 211                   Kenya                   40.71
# 212                  Gambia                   65.74
# 213                 Senegal                   52.72
# 214           Guinea-Bissau                   90.92
# 215            Sierra Leone                   73.29
# 216                  Uganda                   60.82
# 217                 Lesotho                   50.48
# 218              Madagascar                   44.88
# 219                  Malawi                   48.01
# 220              Mozambique                   72.42
# 221               Mauritius                   10.59
# 222                 Mayotte                   56.29
# 223               Swaziland                   54.82
# 224                 Reunion                    7.50
# 225            Saint Helena                   17.63
# 226   Sao Tome and Principe                   49.16
# 227              Seychelles                   10.77
#
# [228 rows x 2 columns]

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [country, infant_mortality_rates]
# Index: []

# %%
df.sort(['infant_mortality_rates']).head(10)
# Out:
#             country  infant_mortality_rates
# 36           Monaco                    1.81
# 90            Japan                    2.13
# 109         Bermuda                    2.48
# 34           Norway                    2.48
# 98        Singapore                    2.53
# 35           Sweden                    2.60
# 8    Czech Republic                    2.63
# 72        Hong Kong                    2.73
# 73            Macao                    3.13
# 39          Iceland                    3.15

# %%
popu_list = []

for element in document_tree.iterfind('country'):
    if element.find('province') == None:
        for subelement in element.iterfind('city'):
            if subelement.find('population') == None:
                continue
            popu_list.append({subelement.find('name').text: subelement.findall('population')})
    else:
        for element in element.iterfind('province'):
            for subelement in element.iterfind('city'):
                if subelement.find('population') == None:
                    continue
                popu_list.append({subelement.find('name').text: subelement.findall('population')})

# %%
popu_list
# Out:
# [{'Tirana': [<Element 'population' at 0x1048409d0>,
#    <Element 'population' at 0x104840a10>,
#    <Element 'population' at 0x104840a50>]},
#  {u'Shkod\xebr': [<Element 'population' at 0x104840b90>,
#    <Element 'population' at 0x104840bd0>]},
#  {u'Durr\xebs': [<Element 'population' at 0x104840d50>,
#    <Element 'population' at 0x104840d90>]},
#  {u'Vlor\xeb': [<Element 'population' at 0x104840f10>,
#    <Element 'population' at 0x104840f50>]},
#  {'Elbasan': [<Element 'population' at 0x10484f110>,
#    <Element 'population' at 0x10484f150>]},
#  {u'Kor\xe7\xeb': [<Element 'population' at 0x10484f290>,
#    <Element 'population' at 0x10484f2d0>]},
#  {'Kavala': [<Element 'population' at 0x10484ff90>,
#    <Element 'population' at 0x10484ffd0>,
#    <Element 'population' at 0x10485c050>,
#    <Element 'population' at 0x10485c090>]},
#  {'Athina': [<Element 'population' at 0x10485c450>,
#    <Element 'population' at 0x10485c490>,
#    <Element 'population' at 0x10485c4d0>,
#    <Element 'population' at 0x10485c510>]},
#  {'Peiraias': [<Element 'population' at 0x10485c690>,
#    <Element 'population' at 0x10485c6d0>,
#    <Element 'population' at 0x10485c710>,
#    <Element 'population' at 0x10485c750>]},
#  {'Peristeri': [<Element 'population' at 0x10485c8d0>,
#    <Element 'population' at 0x10485c910>,
#    <Element 'population' at 0x10485c950>]},
#  {'Acharnes': [<Element 'population' at 0x10485ca50>,
#    <Element 'population' at 0x10485ca90>,
#    <Element 'population' at 0x10485cad0>]},
#  {'Patra': [<Element 'population' at 0x10485ce10>,
#    <Element 'population' at 0x10485ce50>,
#    <Element 'population' at 0x10485ce90>,
#    <Element 'population' at 0x10485ced0>]},
#  {'Kerkyra': [<Element 'population' at 0x10486b510>,
#    <Element 'population' at 0x10486b550>,
#    <Element 'population' at 0x10486b590>]},
#  {'Ioannina': [<Element 'population' at 0x10486b8d0>,
#    <Element 'population' at 0x10486b910>,
#    <Element 'population' at 0x10486b950>]},
#  {'Thessaloniki': [<Element 'population' at 0x10486bd90>,
#    <Element 'population' at 0x10486bdd0>,
#    <Element 'population' at 0x10486be10>,
#    <Element 'population' at 0x10486be50>]},
#  {'Iraklio': [<Element 'population' at 0x104877210>,
#    <Element 'population' at 0x104877250>,
#    <Element 'population' at 0x104877290>,
#    <Element 'population' at 0x1048772d0>]},
#  {'Chania': [<Element 'population' at 0x104877450>,
#    <Element 'population' at 0x104877490>,
#    <Element 'population' at 0x1048774d0>]},
#  {'Rhodes': [<Element 'population' at 0x104877a10>,
#    <Element 'population' at 0x104877a50>,
#    <Element 'population' at 0x104877a90>]},
#  {'Lamia': [<Element 'population' at 0x1048ca050>]},
#  {'Chalkida': [<Element 'population' at 0x1048ca190>,
#    <Element 'population' at 0x1048ca1d0>,
#    <Element 'population' at 0x1048ca210>]},
#  {'Larissa': [<Element 'population' at 0x1048ca510>,
#    <Element 'population' at 0x1048ca550>,
#    <Element 'population' at 0x1048ca590>,
#    <Element 'population' at 0x1048ca5d0>]},
#  {'Volos': [<Element 'population' at 0x1048ca6d0>,
#    <Element 'population' at 0x1048ca710>,
#    <Element 'population' at 0x1048ca750>,
#    <Element 'population' at 0x1048ca790>]},
#  {'Karyes': [<Element 'population' at 0x1048cad50>]},
#  {'Skopje': [<Element 'population' at 0x1048d8a90>,
#    <Element 'population' at 0x1048d8ad0>]},
#  {'Kumanovo': [<Element 'population' at 0x1048d8c90>,
#    <Element 'population' at 0x1048d8cd0>]},
#  {'Beograd': [<Element 'population' at 0x1048e4a10>,
#    <Element 'population' at 0x1048e4a50>,
#    <Element 'population' at 0x1048e4a90>]},
#  {'Novi Sad': [<Element 'population' at 0x1048e4c50>,
#    <Element 'population' at 0x1048e4c90>]},
#  {u'Ni\u0161': [<Element 'population' at 0x1048e4dd0>,
#    <Element 'population' at 0x1048e4e10>]},
#  {'Podgorica': [<Element 'population' at 0x1048f1a50>,
#    <Element 'population' at 0x1048f1a90>]},
#  {'Prishtine': [<Element 'population' at 0x1048fe310>,
#    <Element 'population' at 0x1048fe350>,
#    <Element 'population' at 0x1048fe390>]},
#  {'Andorra la Vella': [<Element 'population' at 0x1048fed90>,
#    <Element 'population' at 0x1048fedd0>,
#    <Element 'population' at 0x1048fee10>]},
#  {'Strasbourg': [<Element 'population' at 0x10490aad0>,
#    <Element 'population' at 0x10490ab10>,
#    <Element 'population' at 0x10490ab50>,
#    <Element 'population' at 0x10490ab90>]},
#  {'Mulhouse': [<Element 'population' at 0x10490ac90>,
#    <Element 'population' at 0x10490acd0>,
#    <Element 'population' at 0x10490ad10>,
#    <Element 'population' at 0x10490ad50>]},
#  {'Bordeaux': [<Element 'population' at 0x104916090>,
#    <Element 'population' at 0x1049160d0>,
#    <Element 'population' at 0x104916110>,
#    <Element 'population' at 0x104916150>]},
#  {'Clermont-Ferrand': [<Element 'population' at 0x104916490>,
#    <Element 'population' at 0x1049164d0>,
#    <Element 'population' at 0x104916510>,
#    <Element 'population' at 0x104916550>]},
#  {'Caen': [<Element 'population' at 0x104916850>,
#    <Element 'population' at 0x104916890>,
#    <Element 'population' at 0x1049168d0>,
#    <Element 'population' at 0x104916910>]},
#  {'Rennes': [<Element 'population' at 0x104916c10>,
#    <Element 'population' at 0x104916c50>,
#    <Element 'population' at 0x104916c90>,
#    <Element 'population' at 0x104916cd0>]},
#  {'Brest': [<Element 'population' at 0x104916d90>,
#    <Element 'population' at 0x104916dd0>,
#    <Element 'population' at 0x104916e10>,
#    <Element 'population' at 0x104916e50>]},
#  {'Dijon': [<Element 'population' at 0x1049261d0>,
#    <Element 'population' at 0x104926210>,
#    <Element 'population' at 0x104926250>,
#    <Element 'population' at 0x104926290>]},
#  {u'Orl\xe9ans': [<Element 'population' at 0x104926590>,
#    <Element 'population' at 0x1049265d0>,
#    <Element 'population' at 0x104926610>,
#    <Element 'population' at 0x104926650>]},
#  {'Tours': [<Element 'population' at 0x104926750>,
#    <Element 'population' at 0x104926790>,
#    <Element 'population' at 0x1049267d0>,
#    <Element 'population' at 0x104926810>]},
#  {'Reims': [<Element 'population' at 0x104926b50>,
#    <Element 'population' at 0x104926b90>,
#    <Element 'population' at 0x1043ac190>,
#    <Element 'population' at 0x1043a6c90>]},
#  {'Ajaccio': [<Element 'population' at 0x1037c6a10>,
#    <Element 'population' at 0x1037c6e90>,
#    <Element 'population' at 0x1037c6f50>,
#    <Element 'population' at 0x1037c63d0>]},
#  {u'Besan\xe7on': [<Element 'population' at 0x1037dc410>,
#    <Element 'population' at 0x1037dc4d0>,
#    <Element 'population' at 0x1037dc590>,
#    <Element 'population' at 0x1037dc650>]},
#  {'Rouen': [<Element 'population' at 0x1037e3050>,
#    <Element 'population' at 0x1037e3110>,
#    <Element 'population' at 0x1037e31d0>,
#    <Element 'population' at 0x1037e3290>]},
#  {'Le Havre': [<Element 'population' at 0x1037e3590>,
#    <Element 'population' at 0x1037e3650>,
#    <Element 'population' at 0x1037e3710>,
#    <Element 'population' at 0x1037e37d0>]},
#  {'Paris': [<Element 'population' at 0x104926dd0>,
#    <Element 'population' at 0x104926e10>,
#    <Element 'population' at 0x104926e50>,
#    <Element 'population' at 0x104926e90>]},
#  {'Boulogne-Billancourt': [<Element 'population' at 0x104939050>,
#    <Element 'population' at 0x104939090>,
#    <Element 'population' at 0x1049390d0>,
#    <Element 'population' at 0x104939110>]},
#  {'Argenteuil': [<Element 'population' at 0x104939210>,
#    <Element 'population' at 0x104939250>]},
#  {'Montreuil': [<Element 'population' at 0x104939350>,
#    <Element 'population' at 0x104939390>]},
#  {'Saint-Paul': [<Element 'population' at 0x104939450>,
#    <Element 'population' at 0x104939490>,
#    <Element 'population' at 0x1049394d0>]},
#  {'Montpellier': [<Element 'population' at 0x104939850>,
#    <Element 'population' at 0x104939890>,
#    <Element 'population' at 0x1049398d0>,
#    <Element 'population' at 0x104939910>]},
#  {u'N\xeemes': [<Element 'population' at 0x1049399d0>,
#    <Element 'population' at 0x104939a10>,
#    <Element 'population' at 0x104939a50>,
#    <Element 'population' at 0x104939a90>]},
#  {'Perpignan': [<Element 'population' at 0x104939b50>,
#    <Element 'population' at 0x104939b90>,
#    <Element 'population' at 0x104939bd0>,
#    <Element 'population' at 0x104939c10>]},
#  {'Limoges': [<Element 'population' at 0x104939f50>,
#    <Element 'population' at 0x104939f90>,
#    <Element 'population' at 0x104939fd0>,
#    <Element 'population' at 0x104949050>]},
#  {'Metz': [<Element 'population' at 0x104949350>,
#    <Element 'population' at 0x104949390>,
#    <Element 'population' at 0x1049493d0>,
#    <Element 'population' at 0x104949410>]},
#  {'Nancy': [<Element 'population' at 0x104949590>,
#    <Element 'population' at 0x1049495d0>,
#    <Element 'population' at 0x104949610>,
#    <Element 'population' at 0x104949650>]},
#  {'Toulouse': [<Element 'population' at 0x104949990>,
#    <Element 'population' at 0x1049499d0>,
#    <Element 'population' at 0x104949a10>,
#    <Element 'population' at 0x104949a50>]},
#  {'Lille': [<Element 'population' at 0x104949d90>,
#    <Element 'population' at 0x104949dd0>,
#    <Element 'population' at 0x104949e10>,
#    <Element 'population' at 0x104949e50>]},
#  {'Nantes': [<Element 'population' at 0x104957190>,
#    <Element 'population' at 0x1049571d0>,
#    <Element 'population' at 0x104957210>,
#    <Element 'population' at 0x104957250>]},
#  {'Angers': [<Element 'population' at 0x104957350>,
#    <Element 'population' at 0x104957390>,
#    <Element 'population' at 0x1049573d0>,
#    <Element 'population' at 0x104957410>]},
#  {'Le Mans': [<Element 'population' at 0x1049574d0>,
#    <Element 'population' at 0x104957510>,
#    <Element 'population' at 0x104957550>,
#    <Element 'population' at 0x104957590>]},
#  {'Amiens': [<Element 'population' at 0x104957890>,
#    <Element 'population' at 0x1049578d0>,
#    <Element 'population' at 0x104957910>,
#    <Element 'population' at 0x104957950>]},
#  {'Poitiers': [<Element 'population' at 0x104957bd0>,
#    <Element 'population' at 0x104957c10>,
#    <Element 'population' at 0x104957c50>,
#    <Element 'population' at 0x104957c90>]},
#  {'Marseille': [<Element 'population' at 0x104957f90>,
#    <Element 'population' at 0x104957fd0>,
#    <Element 'population' at 0x104965050>,
#    <Element 'population' at 0x104965090>]},
#  {'Nice': [<Element 'population' at 0x104965210>,
#    <Element 'population' at 0x104965250>,
#    <Element 'population' at 0x104965290>,
#    <Element 'population' at 0x1049652d0>]},
#  {'Toulon': [<Element 'population' at 0x1049653d0>,
#    <Element 'population' at 0x104965410>,
#    <Element 'population' at 0x104965450>,
#    <Element 'population' at 0x104965490>]},
#  {'Aix-en-Provence': [<Element 'population' at 0x104965590>,
#    <Element 'population' at 0x1049655d0>,
#    <Element 'population' at 0x104965610>,
#    <Element 'population' at 0x104965650>]},
#  {'Lyon': [<Element 'population' at 0x104965950>,
#    <Element 'population' at 0x104965990>,
#    <Element 'population' at 0x1049659d0>,
#    <Element 'population' at 0x104965a10>]},
#  {'Grenoble': [<Element 'population' at 0x104965b50>,
#    <Element 'population' at 0x104965b90>,
#    <Element 'population' at 0x104965bd0>,
#    <Element 'population' at 0x104965c10>]},
#  {u'Saint-\xc9tienne': [<Element 'population' at 0x104965d10>,
#    <Element 'population' at 0x104965d50>,
#    <Element 'population' at 0x104965d90>,
#    <Element 'population' at 0x104965dd0>]},
#  {'Villeurbanne': [<Element 'population' at 0x104965e90>,
#    <Element 'population' at 0x104965ed0>,
#    <Element 'population' at 0x104965f10>,
#    <Element 'population' at 0x104965f50>]},
#  {'Sevilla': [<Element 'population' at 0x104971bd0>,
#    <Element 'population' at 0x104971c10>,
#    <Element 'population' at 0x104971c50>,
#    <Element 'population' at 0x104971c90>]},
#  {u'Almer\xeda': [<Element 'population' at 0x104971d90>,
#    <Element 'population' at 0x104971dd0>,
#    <Element 'population' at 0x104971e10>,
#    <Element 'population' at 0x104971e50>]},
#  {u'C\xe1diz': [<Element 'population' at 0x104971fd0>,
#    <Element 'population' at 0x10497f050>,
#    <Element 'population' at 0x10497f090>,
#    <Element 'population' at 0x10497f0d0>]},
#  {u'C\xf3rdoba': [<Element 'population' at 0x10497f1d0>,
#    <Element 'population' at 0x10497f210>,
#    <Element 'population' at 0x10497f250>,
#    <Element 'population' at 0x10497f290>]},
#  {'Granada': [<Element 'population' at 0x10497f390>,
#    <Element 'population' at 0x10497f3d0>,
#    <Element 'population' at 0x10497f410>,
#    <Element 'population' at 0x10497f450>]},
#  {'Huelva': [<Element 'population' at 0x10497f510>,
#    <Element 'population' at 0x10497f550>,
#    <Element 'population' at 0x10497f590>,
#    <Element 'population' at 0x10497f5d0>]},
#  {u'M\xe1laga': [<Element 'population' at 0x10497f6d0>,
#    <Element 'population' at 0x10497f710>,
#    <Element 'population' at 0x10497f750>,
#    <Element 'population' at 0x10497f790>]},
#  {'Jerez de la Frontera': [<Element 'population' at 0x10497f910>,
#    <Element 'population' at 0x10497f950>,
#    <Element 'population' at 0x10497f990>,
#    <Element 'population' at 0x10497f9d0>]},
#  {u'Ja\xe9n': [<Element 'population' at 0x10497fa90>,
#    <Element 'population' at 0x10497fad0>,
#    <Element 'population' at 0x10497fb10>,
#    <Element 'population' at 0x10497fb50>]},
#  {'Algeciras': [<Element 'population' at 0x10497fc10>,
#    <Element 'population' at 0x10497fc50>,
#    <Element 'population' at 0x10497fc90>,
#    <Element 'population' at 0x10497fcd0>]},
#  {'Marbella': [<Element 'population' at 0x10497fdd0>,
#    <Element 'population' at 0x10497fe10>,
#    <Element 'population' at 0x10497fe50>]},
#  {'Dos Hermanas': [<Element 'population' at 0x10497ff50>,
#    <Element 'population' at 0x10497ff90>,
#    <Element 'population' at 0x10497ffd0>]},
#  {'Zaragoza': [<Element 'population' at 0x10498d290>,
#    <Element 'population' at 0x10498d2d0>,
#    <Element 'population' at 0x10498d310>,
#    <Element 'population' at 0x10498d350>]},
#  {'Oviedo': [<Element 'population' at 0x10498d610>,
#    <Element 'population' at 0x10498d650>,
#    <Element 'population' at 0x10498d690>,
#    <Element 'population' at 0x10498d6d0>]},
#  {u'Gij\xf3n': [<Element 'population' at 0x10498d790>,
#    <Element 'population' at 0x10498d7d0>,
#    <Element 'population' at 0x10498d810>,
#    <Element 'population' at 0x10498d850>]},
#  {'Palma de Mallorca': [<Element 'population' at 0x10498db10>,
#    <Element 'population' at 0x10498db50>,
#    <Element 'population' at 0x10498db90>,
#    <Element 'population' at 0x10498dbd0>]},
#  {'Vitoria-Gasteiz': [<Element 'population' at 0x10498ded0>,
#    <Element 'population' at 0x10498df10>,
#    <Element 'population' at 0x10498df50>,
#    <Element 'population' at 0x10498df90>]},
#  {'Bilbao': [<Element 'population' at 0x10499b090>,
#    <Element 'population' at 0x10499b0d0>,
#    <Element 'population' at 0x10499b110>,
#    <Element 'population' at 0x10499b150>]},
#  {'Barakaldo': [<Element 'population' at 0x10499b250>,
#    <Element 'population' at 0x10499b290>,
#    <Element 'population' at 0x10499b2d0>,
#    <Element 'population' at 0x10499b310>]},
#  {'Donostia': [<Element 'population' at 0x10499b450>,
#    <Element 'population' at 0x10499b490>,
#    <Element 'population' at 0x10499b4d0>,
#    <Element 'population' at 0x10499b510>]},
#  {'Santa Cruz de Tenerife': [<Element 'population' at 0x10499b890>,
#    <Element 'population' at 0x10499b8d0>,
#    <Element 'population' at 0x10499b910>,
#    <Element 'population' at 0x10499b950>]},
#  {u'San Crist\xf3bal de La Laguna': [<Element 'population' at 0x10499ba90>,
#    <Element 'population' at 0x10499bb10>,
#    <Element 'population' at 0x10499bb50>,
#    <Element 'population' at 0x10499bb90>]},
#  {'Las Palmas de Gran Canaria': [<Element 'population' at 0x10499bdd0>,
#    <Element 'population' at 0x10499be10>,
#    <Element 'population' at 0x10499be50>,
#    <Element 'population' at 0x10499be90>]},
#  {'Telde': [<Element 'population' at 0x10499bfd0>,
#    <Element 'population' at 0x1049a9050>,
#    <Element 'population' at 0x1049a9090>]},
#  {'Santander': [<Element 'population' at 0x1049a93d0>,
#    <Element 'population' at 0x1049a9410>,
#    <Element 'population' at 0x1049a9450>,
#    <Element 'population' at 0x1049a9490>]},
#  {'Valladolid': [<Element 'population' at 0x1049a9750>,
#    <Element 'population' at 0x1049a9790>,
#    <Element 'population' at 0x1049a97d0>,
#    <Element 'population' at 0x1049a9810>]},
#  {'Burgos': [<Element 'population' at 0x1049a9910>,
#    <Element 'population' at 0x1049a9950>,
#    <Element 'population' at 0x1049a9990>,
#    <Element 'population' at 0x1049a99d0>]},
#  {u'Le\xf3n': [<Element 'population' at 0x1049a9a90>,
#    <Element 'population' at 0x1049a9ad0>,
#    <Element 'population' at 0x1049a9b10>,
#    <Element 'population' at 0x1049a9b50>]},
#  {'Salamanca': [<Element 'population' at 0x1049a9c10>,
#    <Element 'population' at 0x1049a9c50>,
#    <Element 'population' at 0x1049a9c90>,
#    <Element 'population' at 0x1049a9cd0>]},
#  {'Albacete': [<Element 'population' at 0x1049b6050>,
#    <Element 'population' at 0x1049b6090>,
#    <Element 'population' at 0x1049b60d0>,
#    <Element 'population' at 0x1049b6110>]},
#  {'Barcelona': [<Element 'population' at 0x1049b6410>,
#    <Element 'population' at 0x1049b6450>,
#    <Element 'population' at 0x1049b6490>,
#    <Element 'population' at 0x1049b64d0>]},
#  {'Lleida': [<Element 'population' at 0x1049b65d0>,
#    <Element 'population' at 0x1049b6610>,
#    <Element 'population' at 0x1049b6650>,
#    <Element 'population' at 0x1049b6690>]},
#  {'Tarragona': [<Element 'population' at 0x1049b6750>,
#    <Element 'population' at 0x1049b6790>,
#    <Element 'population' at 0x1049b67d0>,
#    <Element 'population' at 0x1049b6810>]},
#  {'Reus': [<Element 'population' at 0x1049b6910>,
#    <Element 'population' at 0x1049b6950>,
#    <Element 'population' at 0x1049b6990>]},
#  {'Hospitalet de Llobregat': [<Element 'population' at 0x1049b6a90>,
#    <Element 'population' at 0x1049b6ad0>,
#    <Element 'population' at 0x1049b6b10>,
#    <Element 'population' at 0x1049b6b50>]},
#  {'Badalona': [<Element 'population' at 0x1049b6c10>,
#    <Element 'population' at 0x1049b6c50>,
#    <Element 'population' at 0x1049b6c90>,
#    <Element 'population' at 0x1049b6cd0>]},
#  {'Sabadell': [<Element 'population' at 0x1049b6dd0>,
#    <Element 'population' at 0x1049b6e10>,
#    <Element 'population' at 0x1049b6e50>,
#    <Element 'population' at 0x1049b6e90>]},
#  {'Terrassa': [<Element 'population' at 0x1049b6f50>,
#    <Element 'population' at 0x1049b6f90>,
#    <Element 'population' at 0x1049b6fd0>,
#    <Element 'population' at 0x1049c3050>]},
#  {'Santa Coloma de Gramenet': [<Element 'population' at 0x1049c3150>,
#    <Element 'population' at 0x1049c3190>,
#    <Element 'population' at 0x1049c31d0>,
#    <Element 'population' at 0x1049c3210>]},
#  {u'Matar\xf3': [<Element 'population' at 0x1049c32d0>,
#    <Element 'population' at 0x1049c3310>,
#    <Element 'population' at 0x1049c3350>,
#    <Element 'population' at 0x1049c3390>]},
#  {'Badajoz': [<Element 'population' at 0x1049c3610>,
#    <Element 'population' at 0x1049c3650>,
#    <Element 'population' at 0x1049c3690>,
#    <Element 'population' at 0x1049c36d0>]},
#  {u'A Coru\xf1a': [<Element 'population' at 0x1049c3a50>,
#    <Element 'population' at 0x1049c3a90>,
#    <Element 'population' at 0x1049c3ad0>,
#    <Element 'population' at 0x1049c3b10>]},
#  {'Vigo': [<Element 'population' at 0x1049c3c10>,
#    <Element 'population' at 0x1049c3c50>,
#    <Element 'population' at 0x1049c3c90>,
#    <Element 'population' at 0x1049c3cd0>]},
#  {'Ourense': [<Element 'population' at 0x1049c3dd0>,
#    <Element 'population' at 0x1049c3e10>,
#    <Element 'population' at 0x1049c3e50>,
#    <Element 'population' at 0x1049c3e90>]},
#  {'Madrid': [<Element 'population' at 0x1049d1290>,
#    <Element 'population' at 0x1049d12d0>,
#    <Element 'population' at 0x1049d1310>,
#    <Element 'population' at 0x1049d1350>]},
#  {u'M\xf3stoles': [<Element 'population' at 0x1049d1410>,
#    <Element 'population' at 0x1049d1450>,
#    <Element 'population' at 0x1049d1490>,
#    <Element 'population' at 0x1049d14d0>]},
#  {u'Legan\xe9s': [<Element 'population' at 0x1049d1590>,
#    <Element 'population' at 0x1049d15d0>,
#    <Element 'population' at 0x1049d1610>,
#    <Element 'population' at 0x1049d1650>]},
#  {u'Alcal\xe1 de Henares': [<Element 'population' at 0x1049d1710>,
#    <Element 'population' at 0x1049d1750>,
#    <Element 'population' at 0x1049d1790>,
#    <Element 'population' at 0x1049d17d0>]},
#  {'Fuenlabrada': [<Element 'population' at 0x1049d1890>,
#    <Element 'population' at 0x1049d18d0>,
#    <Element 'population' at 0x1049d1910>,
#    <Element 'population' at 0x1049d1950>]},
#  {'Getafe': [<Element 'population' at 0x1049d1a10>,
#    <Element 'population' at 0x1049d1a50>,
#    <Element 'population' at 0x1049d1a90>,
#    <Element 'population' at 0x1049d1ad0>]},
#  {u'Alcorc\xf3n': [<Element 'population' at 0x1049d1b90>,
#    <Element 'population' at 0x1049d1bd0>,
#    <Element 'population' at 0x1049d1c10>,
#    <Element 'population' at 0x1049d1c50>]},
#  {u'Torrej\xf3n de Ardoz': [<Element 'population' at 0x1049d1d10>,
#    <Element 'population' at 0x1049d1d50>,
#    <Element 'population' at 0x1049d1d90>]},
#  {'Parla': [<Element 'population' at 0x1049d1e50>,
#    <Element 'population' at 0x1049d1e90>]},
#  {'Alcobendas': [<Element 'population' at 0x1049d1f50>,
#    <Element 'population' at 0x1049d1f90>,
#    <Element 'population' at 0x1049d1fd0>]},
#  {'Murcia': [<Element 'population' at 0x1049df290>,
#    <Element 'population' at 0x1049df2d0>,
#    <Element 'population' at 0x1049df310>,
#    <Element 'population' at 0x1049df350>]},
#  {'Cartagena': [<Element 'population' at 0x1049df410>,
#    <Element 'population' at 0x1049df450>,
#    <Element 'population' at 0x1049df490>,
#    <Element 'population' at 0x1049df4d0>]},
#  {'Pamplona': [<Element 'population' at 0x1049df7d0>,
#    <Element 'population' at 0x1049df810>,
#    <Element 'population' at 0x1049df850>,
#    <Element 'population' at 0x1049df890>]},
#  {u'Logro\xf1o': [<Element 'population' at 0x1049dfb10>,
#    <Element 'population' at 0x1049dfb50>,
#    <Element 'population' at 0x1049dfb90>,
#    <Element 'population' at 0x1049dfbd0>]},
#  {'Valencia': [<Element 'population' at 0x1049dff10>,
#    <Element 'population' at 0x1049dff50>,
#    <Element 'population' at 0x1049dff90>,
#    <Element 'population' at 0x1049dffd0>]},
#  {'Alicante': [<Element 'population' at 0x1049ed150>,
#    <Element 'population' at 0x1049ed190>,
#    <Element 'population' at 0x1049ed1d0>,
#    <Element 'population' at 0x1049ed210>]},
#  {'Elche': [<Element 'population' at 0x1049ed350>,
#    <Element 'population' at 0x1049ed390>,
#    <Element 'population' at 0x1049ed3d0>,
#    <Element 'population' at 0x1049ed410>]},
#  {u'Castell\xf3n de la Plana': [<Element 'population' at 0x1049ed550>,
#    <Element 'population' at 0x1049ed4d0>,
#    <Element 'population' at 0x1049ed590>,
#    <Element 'population' at 0x1049ed5d0>]},
#  {'Eisenstadt': [<Element 'population' at 0x1049fa590>,
#    <Element 'population' at 0x1049fa5d0>,
#    <Element 'population' at 0x1049fa610>,
#    <Element 'population' at 0x1049fa650>,
#    <Element 'population' at 0x1049fa690>]},
#  {'Klagenfurt': [<Element 'population' at 0x1049faa10>,
#    <Element 'population' at 0x1049faa50>,
#    <Element 'population' at 0x1049faa90>,
#    <Element 'population' at 0x1049faad0>,
#    <Element 'population' at 0x1049fab10>]},
#  {'Villach': [<Element 'population' at 0x1049fabd0>,
#    <Element 'population' at 0x1049fac10>,
#    <Element 'population' at 0x1049fac50>,
#    <Element 'population' at 0x1049fac90>]},
#  {'Wien': [<Element 'population' at 0x104a07350>,
#    <Element 'population' at 0x104a07390>,
#    <Element 'population' at 0x104a073d0>,
#    <Element 'population' at 0x104a07410>,
#    <Element 'population' at 0x104a07450>]},
#  {'Linz': [<Element 'population' at 0x104a07790>,
#    <Element 'population' at 0x104a077d0>,
#    <Element 'population' at 0x104a07810>,
#    <Element 'population' at 0x104a07850>,
#    <Element 'population' at 0x104a07890>]},
#  {'Wels': [<Element 'population' at 0x104a07990>,
#    <Element 'population' at 0x104a079d0>,
#    <Element 'population' at 0x104a07a10>,
#    <Element 'population' at 0x104a07a50>]},
#  {'Innsbruck': [<Element 'population' at 0x104a07d50>,
#    <Element 'population' at 0x104a07d90>,
#    <Element 'population' at 0x104a07dd0>,
#    <Element 'population' at 0x104a07e10>,
#    <Element 'population' at 0x104a07e50>]},
#  {'Graz': [<Element 'population' at 0x104a151d0>,
#    <Element 'population' at 0x104a15210>,
#    <Element 'population' at 0x104a15250>,
#    <Element 'population' at 0x104a15290>,
#    <Element 'population' at 0x104a152d0>]},
#  {'Salzburg': [<Element 'population' at 0x104a15610>,
#    <Element 'population' at 0x104a15650>,
#    <Element 'population' at 0x104a15690>,
#    <Element 'population' at 0x104a156d0>,
#    <Element 'population' at 0x104a15710>]},
#  {u'St. P\xf6lten': [<Element 'population' at 0x104a15ad0>,
#    <Element 'population' at 0x104a15b10>,
#    <Element 'population' at 0x104a15b50>,
#    <Element 'population' at 0x104a15b90>,
#    <Element 'population' at 0x104a15bd0>]},
#  {'Praha': [<Element 'population' at 0x104a23850>,
#    <Element 'population' at 0x104a23890>,
#    <Element 'population' at 0x104a238d0>]},
#  {u'\u010cesk\xe9 Bud\u011bjovice': [<Element 'population' at 0x104a23b10>,
#    <Element 'population' at 0x104a23b50>,
#    <Element 'population' at 0x104a23b90>]},
#  {'Brno': [<Element 'population' at 0x104a23dd0>,
#    <Element 'population' at 0x104a23e10>,
#    <Element 'population' at 0x104a23e50>]},
#  {'Karlovy Vary': [<Element 'population' at 0x104a2f090>,
#    <Element 'population' at 0x104a2f0d0>]},
#  {'Jihlava': [<Element 'population' at 0x104a2f2d0>,
#    <Element 'population' at 0x104a2f310>]},
#  {u'Hradec Kr\xe1lov\xe9': [<Element 'population' at 0x104a2f510>,
#    <Element 'population' at 0x104a2f550>,
#    <Element 'population' at 0x104a2f590>]},
#  {'Liberec': [<Element 'population' at 0x104a2f7d0>,
#    <Element 'population' at 0x104a2f810>,
#    <Element 'population' at 0x104a2f850>]},
#  {'Ostrava': [<Element 'population' at 0x104a2fa50>,
#    <Element 'population' at 0x104a2fa90>,
#    <Element 'population' at 0x104a2fad0>]},
#  {'Olomouc': [<Element 'population' at 0x104a2fd10>,
#    <Element 'population' at 0x104a2fd50>,
#    <Element 'population' at 0x104a2fd90>]},
#  {'Pardubice': [<Element 'population' at 0x104a2ffd0>,
#    <Element 'population' at 0x104a3d050>,
#    <Element 'population' at 0x104a3d090>]},
#  {u'Plze\u0148': [<Element 'population' at 0x104a3d2d0>,
#    <Element 'population' at 0x104a3d310>,
#    <Element 'population' at 0x104a3d350>]},
#  {u'\xdast\xed nad Labem': [<Element 'population' at 0x104a3d710>,
#    <Element 'population' at 0x104a3d750>]},
#  {u'Zl\xedn': [<Element 'population' at 0x104a3d990>,
#    <Element 'population' at 0x104a3d9d0>,
#    <Element 'population' at 0x104a3da10>]},
#  {'Stuttgart': [<Element 'population' at 0x104a4a590>,
#    <Element 'population' at 0x104a4a5d0>,
#    <Element 'population' at 0x104a4a610>,
#    <Element 'population' at 0x104a4a650>]},
#  {'Mannheim': [<Element 'population' at 0x104a4a810>,
#    <Element 'population' at 0x104a4a850>,
#    <Element 'population' at 0x104a4a890>,
#    <Element 'population' at 0x104a4a8d0>]},
#  {'Karlsruhe': [<Element 'population' at 0x104a4aa10>,
#    <Element 'population' at 0x104a4aa50>,
#    <Element 'population' at 0x104a4aa90>,
#    <Element 'population' at 0x104a4aad0>]},
#  {'Freiburg': [<Element 'population' at 0x104a4ac50>,
#    <Element 'population' at 0x104a4ac90>]},
#  {'Heidelberg': [<Element 'population' at 0x104a4ad50>,
#    <Element 'population' at 0x104a4ad90>]},
#  {'Heilbronn': [<Element 'population' at 0x104a4ae90>,
#    <Element 'population' at 0x104a4aed0>]},
#  {'Pforzheim': [<Element 'population' at 0x104a4afd0>,
#    <Element 'population' at 0x104a57050>]},
#  {'Ulm': [<Element 'population' at 0x104a57110>,
#    <Element 'population' at 0x104a57150>]},
#  {'Reutlingen': [<Element 'population' at 0x104a57290>,
#    <Element 'population' at 0x104a572d0>]},
#  {u'M\xfcnchen': [<Element 'population' at 0x104a575d0>,
#    <Element 'population' at 0x104a57610>,
#    <Element 'population' at 0x104a57650>,
#    <Element 'population' at 0x104a57690>]},
#  {u'N\xfcrnberg': [<Element 'population' at 0x104a57790>,
#    <Element 'population' at 0x104a577d0>,
#    <Element 'population' at 0x104a57810>,
#    <Element 'population' at 0x104a57850>]},
#  {'Augsburg': [<Element 'population' at 0x104a57910>,
#    <Element 'population' at 0x104a57950>,
#    <Element 'population' at 0x104a57990>,
#    <Element 'population' at 0x104a579d0>]},
#  {u'W\xfcrzburg': [<Element 'population' at 0x104a57ad0>,
#    <Element 'population' at 0x104a57b10>]},
#  {'Regensburg': [<Element 'population' at 0x104a57c10>,
#    <Element 'population' at 0x104a57c50>]},
#  {'Ingolstadt': [<Element 'population' at 0x104a57d50>,
#    <Element 'population' at 0x104a57d90>]},
#  {u'F\xfcrth': [<Element 'population' at 0x104a57e90>,
#    <Element 'population' at 0x104a57ed0>]},
#  {'Erlangen': [<Element 'population' at 0x104a57f90>,
#    <Element 'population' at 0x104a57fd0>]},
#  {'Berlin': [<Element 'population' at 0x104a652d0>,
#    <Element 'population' at 0x104a65310>,
#    <Element 'population' at 0x104a65350>,
#    <Element 'population' at 0x104a65390>]},
#  {'Potsdam': [<Element 'population' at 0x104a65690>]},
#  {'Cottbus': [<Element 'population' at 0x104a65750>]},
#  {'Bremen': [<Element 'population' at 0x104a65a10>,
#    <Element 'population' at 0x104a65a50>,
#    <Element 'population' at 0x104a65a90>,
#    <Element 'population' at 0x104a65ad0>]},
#  {'Bremerhaven': [<Element 'population' at 0x104a65bd0>,
#    <Element 'population' at 0x104a65c10>]},
#  {'Hamburg': [<Element 'population' at 0x104a65f90>,
#    <Element 'population' at 0x104a65fd0>,
#    <Element 'population' at 0x104a73050>,
#    <Element 'population' at 0x104a73090>]},
#  {'Wiesbaden': [<Element 'population' at 0x104a733d0>,
#    <Element 'population' at 0x104a73410>,
#    <Element 'population' at 0x104a73450>,
#    <Element 'population' at 0x104a73490>]},
#  {'Frankfurt am Main': [<Element 'population' at 0x104a73610>,
#    <Element 'population' at 0x104a73650>,
#    <Element 'population' at 0x104a73690>,
#    <Element 'population' at 0x104a736d0>]},
#  {'Kassel': [<Element 'population' at 0x104a737d0>,
#    <Element 'population' at 0x104a73810>]},
#  {'Darmstadt': [<Element 'population' at 0x104a73910>,
#    <Element 'population' at 0x104a73950>]},
#  {'Offenbach am Main': [<Element 'population' at 0x104a73a50>,
#    <Element 'population' at 0x104a73a90>]},
#  {'Schwerin': [<Element 'population' at 0x104a73dd0>,
#    <Element 'population' at 0x104a73e10>]},
#  {'Rostock': [<Element 'population' at 0x104a73f50>,
#    <Element 'population' at 0x104a73f90>]},
#  {'Hannover': [<Element 'population' at 0x104a81390>,
#    <Element 'population' at 0x104a813d0>,
#    <Element 'population' at 0x104a81410>,
#    <Element 'population' at 0x104a81450>]},
#  {'Braunschweig': [<Element 'population' at 0x104a81550>,
#    <Element 'population' at 0x104a81590>]},
#  {u'Osnabr\xfcck': [<Element 'population' at 0x104a81650>,
#    <Element 'population' at 0x104a81690>]},
#  {'Oldenburg': [<Element 'population' at 0x104a81750>,
#    <Element 'population' at 0x104a81790>]},
#  {u'G\xf6ttingen': [<Element 'population' at 0x104a81850>,
#    <Element 'population' at 0x104a81890>]},
#  {'Wolfsburg': [<Element 'population' at 0x104a81990>,
#    <Element 'population' at 0x104a819d0>]},
#  {'Salzgitter': [<Element 'population' at 0x104a81ad0>,
#    <Element 'population' at 0x104a81b10>]},
#  {'Hildesheim': [<Element 'population' at 0x104a81bd0>,
#    <Element 'population' at 0x104a81c10>]},
#  {u'D\xfcsseldorf': [<Element 'population' at 0x104a81f10>,
#    <Element 'population' at 0x104a81f50>,
#    <Element 'population' at 0x104a81f90>,
#    <Element 'population' at 0x104a81fd0>]},
#  {u'K\xf6ln': [<Element 'population' at 0x104a8f110>,
#    <Element 'population' at 0x104a8f150>,
#    <Element 'population' at 0x104a8f190>,
#    <Element 'population' at 0x104a8f1d0>]},
#  {'Essen': [<Element 'population' at 0x104a8f2d0>,
#    <Element 'population' at 0x104a8f310>,
#    <Element 'population' at 0x104a8f350>,
#    <Element 'population' at 0x104a8f390>]},
#  {'Dortmund': [<Element 'population' at 0x104a8f450>,
#    <Element 'population' at 0x104a8f490>,
#    <Element 'population' at 0x104a8f4d0>,
#    <Element 'population' at 0x104a8f510>]},
#  {'Duisburg': [<Element 'population' at 0x104a8f5d0>,
#    <Element 'population' at 0x104a8f610>,
#    <Element 'population' at 0x104a8f650>,
#    <Element 'population' at 0x104a8f690>]},
#  {'Bochum': [<Element 'population' at 0x104a8f790>,
#    <Element 'population' at 0x104a8f7d0>,
#    <Element 'population' at 0x104a8f810>,
#    <Element 'population' at 0x104a8f850>]},
#  {'Wuppertal': [<Element 'population' at 0x104a8f910>,
#    <Element 'population' at 0x104a8f950>,
#    <Element 'population' at 0x104a8f990>,
#    <Element 'population' at 0x104a8f9d0>]},
#  {'Bielefeld': [<Element 'population' at 0x104a8fa90>,
#    <Element 'population' at 0x104a8fad0>,
#    <Element 'population' at 0x104a8fb10>,
#    <Element 'population' at 0x104a8fb50>]},
#  {'Gelsenkirchen': [<Element 'population' at 0x104a8fc10>,
#    <Element 'population' at 0x104a8fc50>,
#    <Element 'population' at 0x104a8fc90>,
#    <Element 'population' at 0x104a8fcd0>]},
#  {'Bonn': [<Element 'population' at 0x104a8fe10>,
#    <Element 'population' at 0x104a8fe50>,
#    <Element 'population' at 0x104a8fe90>,
#    <Element 'population' at 0x104a8fed0>]},
#  {u'M\xf6nchengladbach': [<Element 'population' at 0x104a8ffd0>,
#    <Element 'population' at 0x104a9e050>,
#    <Element 'population' at 0x104a9e090>,
#    <Element 'population' at 0x104a9e0d0>]},
#  {u'M\xfcnster': [<Element 'population' at 0x104a9e190>,
#    <Element 'population' at 0x104a9e1d0>,
#    <Element 'population' at 0x104a9e210>,
#    <Element 'population' at 0x104a9e250>]},
#  {'Krefeld': [<Element 'population' at 0x104a9e310>,
#    <Element 'population' at 0x104a9e350>]},
#  {'Aachen': [<Element 'population' at 0x104a9e450>,
#    <Element 'population' at 0x104a9e490>]},
#  {'Oberhausen': [<Element 'population' at 0x104a9e550>,
#    <Element 'population' at 0x104a9e590>]},
#  {'Hagen': [<Element 'population' at 0x104a9e650>,
#    <Element 'population' at 0x104a9e690>]},
#  {'Hamm': [<Element 'population' at 0x104a9e750>,
#    <Element 'population' at 0x104a9e790>]},
#  {'Herne': [<Element 'population' at 0x104a9e850>,
#    <Element 'population' at 0x104a9e890>]},
#  {u'M\xfclheim an der Ruhr': [<Element 'population' at 0x104a9e990>,
#    <Element 'population' at 0x104a9e9d0>]},
#  {'Solingen': [<Element 'population' at 0x104a9ea90>,
#    <Element 'population' at 0x104a9ead0>]},
#  {'Leverkusen': [<Element 'population' at 0x104a9eb90>,
#    <Element 'population' at 0x104a9ebd0>]},
#  {'Neuss': [<Element 'population' at 0x104a9ecd0>,
#    <Element 'population' at 0x104a9ed10>]},
#  {'Paderborn': [<Element 'population' at 0x104a9ee10>,
#    <Element 'population' at 0x104a9ee50>]},
#  {'Recklinghausen': [<Element 'population' at 0x104a9ef10>,
#    <Element 'population' at 0x104a9ef50>]},
#  {'Remscheid': [<Element 'population' at 0x104aac050>,
#    <Element 'population' at 0x104aac090>]},
#  {'Bottrop': [<Element 'population' at 0x104aac150>,
#    <Element 'population' at 0x104aac190>]},
#  {'Siegen': [<Element 'population' at 0x104aac250>,
#    <Element 'population' at 0x104aac290>]},
#  {'Moers': [<Element 'population' at 0x104aac350>,
#    <Element 'population' at 0x104aac390>]},
#  {'Witten': [<Element 'population' at 0x104aac450>,
#    <Element 'population' at 0x104aac490>]},
#  {'Bergisch Gladbach': [<Element 'population' at 0x104aac550>,
#    <Element 'population' at 0x104aac590>]},
#  {'Mainz': [<Element 'population' at 0x104aac890>,
#    <Element 'population' at 0x104aac8d0>]},
#  {'Ludwigshafen': [<Element 'population' at 0x104aac9d0>,
#    <Element 'population' at 0x104aaca10>]},
#  {'Koblenz': [<Element 'population' at 0x104aacb10>,
#    <Element 'population' at 0x104aacb50>]},
#  {'Kaiserslautern': [<Element 'population' at 0x104aacc90>,
#    <Element 'population' at 0x104aaccd0>]},
#  {'Trier': [<Element 'population' at 0x104aacd90>,
#    <Element 'population' at 0x104aacdd0>]},
#  {u'Saarbr\xfccken': [<Element 'population' at 0x104ab9110>,
#    <Element 'population' at 0x104ab9150>]},
#  {'Dresden': [<Element 'population' at 0x104ab9450>,
#    <Element 'population' at 0x104ab9490>,
#    <Element 'population' at 0x104ab94d0>,
#    <Element 'population' at 0x104ab9510>]},
#  {'Leipzig': [<Element 'population' at 0x104ab9610>,
#    <Element 'population' at 0x104ab9650>,
#    <Element 'population' at 0x104ab9690>,
#    <Element 'population' at 0x104ab96d0>]},
#  {'Chemnitz': [<Element 'population' at 0x104ab9790>,
#    <Element 'population' at 0x104ab97d0>]},
#  {'Zwickau': [<Element 'population' at 0x104ab9890>,
#    <Element 'population' at 0x104ab98d0>]},
#  {'Magdeburg': [<Element 'population' at 0x104ab9b90>,
#    <Element 'population' at 0x104ab9bd0>]},
#  {'Halle': [<Element 'population' at 0x104ab9cd0>,
#    <Element 'population' at 0x104ab9d10>]},
#  {'Kiel': [<Element 'population' at 0x104ac6050>,
#    <Element 'population' at 0x104ac6090>]},
#  {u'L\xfcbeck': [<Element 'population' at 0x104ac6190>,
#    <Element 'population' at 0x104ac61d0>]},
#  {'Erfurt': [<Element 'population' at 0x104ac64d0>]},
#  {'Gera': [<Element 'population' at 0x104ac6590>]},
#  {'Jena': [<Element 'population' at 0x104ac6650>]},
#  {u'P\xe9cs': [<Element 'population' at 0x104ad3290>,
#    <Element 'population' at 0x104ad32d0>,
#    <Element 'population' at 0x104ad3310>,
#    <Element 'population' at 0x104ad3350>]},
#  {u'Kecskem\xe9t': [<Element 'population' at 0x104ad3590>,
#    <Element 'population' at 0x104ad35d0>,
#    <Element 'population' at 0x104ad3610>,
#    <Element 'population' at 0x104ad3650>]},
#  {u'B\xe9k\xe9scsaba': [<Element 'population' at 0x104ad3910>,
#    <Element 'population' at 0x104ad3950>,
#    <Element 'population' at 0x104ad3990>]},
#  {'Miskolc': [<Element 'population' at 0x104ad3bd0>,
#    <Element 'population' at 0x104ad3c10>,
#    <Element 'population' at 0x104ad3c50>,
#    <Element 'population' at 0x104ad3c90>]},
#  {'Szeged': [<Element 'population' at 0x104ad3ed0>,
#    <Element 'population' at 0x104ad3f10>,
#    <Element 'population' at 0x104ad3f50>,
#    <Element 'population' at 0x104ad3f90>]},
#  {u'Sz\xe9kesfeh\xe9rv\xe1r': [<Element 'population' at 0x104ae02d0>,
#    <Element 'population' at 0x104ae0310>,
#    <Element 'population' at 0x104ae0350>,
#    <Element 'population' at 0x104ae0390>]},
#  {u'Gy\u0151r': [<Element 'population' at 0x104ae05d0>,
#    <Element 'population' at 0x104ae0610>,
#    <Element 'population' at 0x104ae0650>,
#    <Element 'population' at 0x104ae0690>]},
#  {'Debrecen': [<Element 'population' at 0x104ae0910>,
#    <Element 'population' at 0x104ae0950>,
#    <Element 'population' at 0x104ae0990>,
#    <Element 'population' at 0x104ae09d0>]},
#  {'Eger': [<Element 'population' at 0x104ae0c10>,
#    <Element 'population' at 0x104ae0c50>,
#    <Element 'population' at 0x104ae0c90>]},
#  {u'Tatab\xe1nya': [<Element 'population' at 0x104ae0f50>,
#    <Element 'population' at 0x104ae0f90>,
#    <Element 'population' at 0x104ae0fd0>]},
#  {u'Kaposv\xe1r': [<Element 'population' at 0x104aee710>,
#    <Element 'population' at 0x104aee750>,
#    <Element 'population' at 0x104aee790>]},
#  {u'Ny\xedregyh\xe1za': [<Element 'population' at 0x104aee9d0>,
#    <Element 'population' at 0x104aeea10>,
#    <Element 'population' at 0x104aeea50>,
#    <Element 'population' at 0x104aeea90>]},
#  {'Szolnok': [<Element 'population' at 0x104aeecd0>,
#    <Element 'population' at 0x104aeed10>,
#    <Element 'population' at 0x104aeed50>]},
#  {'Szombathely': [<Element 'population' at 0x104afa310>,
#    <Element 'population' at 0x104afa350>,
#    <Element 'population' at 0x104afa390>]},
#  {u'Veszpr\xe9m': [<Element 'population' at 0x104afa650>,
#    <Element 'population' at 0x104afa690>,
#    <Element 'population' at 0x104afa6d0>]},
#  {'Zalaegerszeg': [<Element 'population' at 0x104afa990>,
#    <Element 'population' at 0x104afa9d0>,
#    <Element 'population' at 0x104afaa10>]},
#  {'Budapest': [<Element 'population' at 0x104afad50>,
#    <Element 'population' at 0x104afad90>,
#    <Element 'population' at 0x104afadd0>,
#    <Element 'population' at 0x104afae10>]},
#  {'Novara': [<Element 'population' at 0x104b06c50>,
#    <Element 'population' at 0x104b06c90>,
#    <Element 'population' at 0x104b06cd0>]},
#  {'Torino': [<Element 'population' at 0x104b06e10>,
#    <Element 'population' at 0x104b06e50>,
#    <Element 'population' at 0x104b06e90>]},
#  {u'B\xe9rgamo': [<Element 'population' at 0x104b13350>,
#    <Element 'population' at 0x104b13390>,
#    <Element 'population' at 0x104b133d0>]},
#  {u'Br\xe9scia': [<Element 'population' at 0x104b13490>,
#    <Element 'population' at 0x104b134d0>,
#    <Element 'population' at 0x104b13510>]},
#  {'Milano': [<Element 'population' at 0x104b13650>,
#    <Element 'population' at 0x104b13690>,
#    <Element 'population' at 0x104b136d0>]},
#  {'Monza': [<Element 'population' at 0x104b13790>,
#    <Element 'population' at 0x104b137d0>,
#    <Element 'population' at 0x104b13810>]},
#  {'Bolzano': [<Element 'population' at 0x104b13ad0>,
#    <Element 'population' at 0x104b13b10>,
#    <Element 'population' at 0x104b13b50>]},
#  {'Trento': [<Element 'population' at 0x104b13cd0>,
#    <Element 'population' at 0x104b13d10>,
#    <Element 'population' at 0x104b13d50>]},
#  {u'P\xe1dova': [<Element 'population' at 0x104b13f90>,
#    <Element 'population' at 0x104b13fd0>,
#    <Element 'population' at 0x104b21050>]},
#  {'Verona': [<Element 'population' at 0x104b21110>,
#    <Element 'population' at 0x104b21150>,
#    <Element 'population' at 0x104b21190>]},
#  {'Vicenza': [<Element 'population' at 0x104b21290>,
#    <Element 'population' at 0x104b212d0>,
#    <Element 'population' at 0x104b21310>]},
#  {u'Ven\xe9zia': [<Element 'population' at 0x104b21450>,
#    <Element 'population' at 0x104b21490>,
#    <Element 'population' at 0x104b214d0>]},
#  {'Trieste': [<Element 'population' at 0x104b217d0>,
#    <Element 'population' at 0x104b21810>,
#    <Element 'population' at 0x104b21850>]},
#  {'La Spezia': [<Element 'population' at 0x104b21a90>,
#    <Element 'population' at 0x104b21ad0>,
#    <Element 'population' at 0x104b21b10>]},
#  {u'G\xe9nova': [<Element 'population' at 0x104b21c90>,
#    <Element 'population' at 0x104b21cd0>,
#    <Element 'population' at 0x104b21d10>]},
#  {'Bologna': [<Element 'population' at 0x104b21fd0>,
#    <Element 'population' at 0x104b2f050>,
#    <Element 'population' at 0x104b2f090>]},
#  {'Ferrara': [<Element 'population' at 0x104b2f150>,
#    <Element 'population' at 0x104b2f190>,
#    <Element 'population' at 0x104b2f1d0>]},
#  {u'Forl\xed': [<Element 'population' at 0x104b2f290>,
#    <Element 'population' at 0x104b2f2d0>,
#    <Element 'population' at 0x104b2f310>]},
#  {u'M\xf3dena': [<Element 'population' at 0x104b2f3d0>,
#    <Element 'population' at 0x104b2f410>,
#    <Element 'population' at 0x104b2f450>]},
#  {'Parma': [<Element 'population' at 0x104b2f510>,
#    <Element 'population' at 0x104b2f550>,
#    <Element 'population' at 0x104b2f590>]},
#  {'Piacenza': [<Element 'population' at 0x104b2f650>,
#    <Element 'population' at 0x104b2f690>,
#    <Element 'population' at 0x104b2f6d0>]},
#  {'Ravenna': [<Element 'population' at 0x104b2f7d0>,
#    <Element 'population' at 0x104b2f810>,
#    <Element 'population' at 0x104b2f850>]},
#  {u"R\xe9ggio nell'Emilia": [<Element 'population' at 0x104b2f910>,
#    <Element 'population' at 0x104b2f950>,
#    <Element 'population' at 0x104b2f990>]},
#  {u'R\xedmini': [<Element 'population' at 0x104b2fa50>,
#    <Element 'population' at 0x104b2fa90>,
#    <Element 'population' at 0x104b2fad0>]},
#  {'Livorno': [<Element 'population' at 0x104b2fd10>,
#    <Element 'population' at 0x104b2fd50>,
#    <Element 'population' at 0x104b2fd90>]},
#  {'Pisa': [<Element 'population' at 0x104b2fe90>,
#    <Element 'population' at 0x104b2fed0>,
#    <Element 'population' at 0x104b2ff10>]},
#  {'Firenze': [<Element 'population' at 0x104b3d0d0>,
#    <Element 'population' at 0x104b3d110>,
#    <Element 'population' at 0x104b3d150>]},
#  {'Prato': [<Element 'population' at 0x104b3d250>,
#    <Element 'population' at 0x104b3d290>,
#    <Element 'population' at 0x104b3d2d0>]},
#  {u'Per\xfagia': [<Element 'population' at 0x104b3d550>,
#    <Element 'population' at 0x104b3d590>,
#    <Element 'population' at 0x104b3d5d0>]},
#  {'Terni': [<Element 'population' at 0x104b3d690>,
#    <Element 'population' at 0x104b3d6d0>,
#    <Element 'population' at 0x104b3d710>]},
#  {'Ancona': [<Element 'population' at 0x104b3d990>,
#    <Element 'population' at 0x104b3d9d0>,
#    <Element 'population' at 0x104b3da10>]},
#  {'Roma': [<Element 'population' at 0x104b3dcd0>,
#    <Element 'population' at 0x104b3dd10>,
#    <Element 'population' at 0x104b3dd50>]},
#  {'Latina': [<Element 'population' at 0x104b3de50>,
#    <Element 'population' at 0x104b3de90>,
#    <Element 'population' at 0x104b3ded0>]},
#  {'Pescara': [<Element 'population' at 0x104b4c110>,
#    <Element 'population' at 0x104b4c150>,
#    <Element 'population' at 0x104b4c190>]},
#  {'Salerno': [<Element 'population' at 0x104b4c790>,
#    <Element 'population' at 0x104b4c7d0>,
#    <Element 'population' at 0x104b4c810>]},
#  {u'N\xe1poli': [<Element 'population' at 0x104b4c990>,
#    <Element 'population' at 0x104b4c9d0>,
#    <Element 'population' at 0x104b4ca10>]},
#  {'Torre del Greco': [<Element 'population' at 0x104b4cb10>,
#    <Element 'population' at 0x104b4cb50>,
#    <Element 'population' at 0x104b4cb90>]},
#  {'Giugliano in Campania': [<Element 'population' at 0x104b4ccd0>,
#    <Element 'population' at 0x104b4cd10>,
#    <Element 'population' at 0x104b4cd50>]},
#  {'Bari': [<Element 'population' at 0x104b4cfd0>,
#    <Element 'population' at 0x104b59050>,
#    <Element 'population' at 0x104b59090>]},
#  {u'F\xf3ggia': [<Element 'population' at 0x104b59190>,
#    <Element 'population' at 0x104b591d0>,
#    <Element 'population' at 0x104b59210>]},
#  {'Lecce': [<Element 'population' at 0x104b592d0>,
#    <Element 'population' at 0x104b59310>,
#    <Element 'population' at 0x104b59350>]},
#  {'Andria': [<Element 'population' at 0x104b59410>,
#    <Element 'population' at 0x104b59450>,
#    <Element 'population' at 0x104b59490>]},
#  {u'T\xe1ranto': [<Element 'population' at 0x104b59550>,
#    <Element 'population' at 0x104b59590>,
#    <Element 'population' at 0x104b595d0>]},
#  {'Catanzaro': [<Element 'population' at 0x104b59ad0>,
#    <Element 'population' at 0x104b59b10>,
#    <Element 'population' at 0x104b59b50>]},
#  {'Cosenza': [<Element 'population' at 0x104b59c10>,
#    <Element 'population' at 0x104b59c50>,
#    <Element 'population' at 0x104b59c90>]},
#  {u'R\xe9ggio di Calabria': [<Element 'population' at 0x104b59d50>,
#    <Element 'population' at 0x104b59d90>,
#    <Element 'population' at 0x104b59dd0>]},
#  {'Palermo': [<Element 'population' at 0x104b660d0>,
#    <Element 'population' at 0x104b66110>,
#    <Element 'population' at 0x104b66150>]},
#  {'Messina': [<Element 'population' at 0x104b66290>,
#    <Element 'population' at 0x104b662d0>,
#    <Element 'population' at 0x104b66310>]},
#  {u'Cat\xe1nia': [<Element 'population' at 0x104b66450>,
#    <Element 'population' at 0x104b66490>,
#    <Element 'population' at 0x104b664d0>]},
#  {'Siracusa': [<Element 'population' at 0x104b66610>,
#    <Element 'population' at 0x104b66650>,
#    <Element 'population' at 0x104b66690>]},
#  {u'C\xe1gliari': [<Element 'population' at 0x104b66990>,
#    <Element 'population' at 0x104b669d0>,
#    <Element 'population' at 0x104b66a10>]},
#  {u'S\xe1ssari': [<Element 'population' at 0x104b66b50>,
#    <Element 'population' at 0x104b66b90>,
#    <Element 'population' at 0x104b66bd0>]},
#  {'Vaduz': [<Element 'population' at 0x104b73590>,
#    <Element 'population' at 0x104b735d0>]},
#  {'Bratislava': [<Element 'population' at 0x104b7f410>,
#    <Element 'population' at 0x104b7f450>]},
#  {u'Bansk\xe1 Bystrica': [<Element 'population' at 0x104b7f6d0>,
#    <Element 'population' at 0x104b7f710>]},
#  {u'\u017dilina': [<Element 'population' at 0x104b7f910>,
#    <Element 'population' at 0x104b7f950>]},
#  {u'Ko\u0161ice': [<Element 'population' at 0x104b7fb90>,
#    <Element 'population' at 0x104b7fbd0>]},
#  {u'Pre\u0161ov': [<Element 'population' at 0x104b7fdd0>,
#    <Element 'population' at 0x104b7fe10>]},
#  {'Nitra': [<Element 'population' at 0x104b8d050>,
#    <Element 'population' at 0x104b8d090>]},
#  {u'Tren\u010d\xedn': [<Element 'population' at 0x104b8d290>,
#    <Element 'population' at 0x104b8d2d0>]},
#  {'Trnava': [<Element 'population' at 0x104b8d510>,
#    <Element 'population' at 0x104b8d550>]},
#  {'Ljubljana': [<Element 'population' at 0x104b9c290>,
#    <Element 'population' at 0x104b9c2d0>,
#    <Element 'population' at 0x104b9c310>,
#    <Element 'population' at 0x104b9c350>]},
#  {'Maribor': [<Element 'population' at 0x104b9c490>,
# ...
#  {'Lisboa': [<Element 'population' at 0x10522a0d0>,
#    <Element 'population' at 0x10522a110>,
#    <Element 'population' at 0x10522a150>]},
#  {'Amadora': [<Element 'population' at 0x10522a290>,
#    <Element 'population' at 0x10522a2d0>,
#    <Element 'population' at 0x10522a310>]},
#  {'Barreiro': [<Element 'population' at 0x10522a3d0>,
#    <Element 'population' at 0x10522a410>]},
#  {'Almada': [<Element 'population' at 0x10522a510>,
#    <Element 'population' at 0x10522a550>]},
#  {'Oporto': [<Element 'population' at 0x10522aa50>,
#    <Element 'population' at 0x10522aa90>,
#    <Element 'population' at 0x10522aad0>]},
#  {'Vila Nova de Gaia': [<Element 'population' at 0x10522ac10>,
#    <Element 'population' at 0x10522ac50>]},
#  {u'Set\xfabal': [<Element 'population' at 0x105236110>,
#    <Element 'population' at 0x105236150>,
#    <Element 'population' at 0x105236190>]},
#  {'Ponta Delgada': [<Element 'population' at 0x1052369d0>]},
#  {'Funchal': [<Element 'population' at 0x105236cd0>,
#    <Element 'population' at 0x105236d10>,
#    <Element 'population' at 0x105236d50>]},
#  {'Newcastle upon Tyne': [<Element 'population' at 0x105243f50>,
#    <Element 'population' at 0x105243f90>,
#    <Element 'population' at 0x105243fd0>]},
#  {'Sunderland': [<Element 'population' at 0x10524f150>,
#    <Element 'population' at 0x10524f190>,
#    <Element 'population' at 0x10524f1d0>]},
#  {'Gateshead': [<Element 'population' at 0x10524f350>,
#    <Element 'population' at 0x10524f390>,
#    <Element 'population' at 0x10524f3d0>]},
#  {'Middlesbrough': [<Element 'population' at 0x10524f510>,
#    <Element 'population' at 0x10524f550>,
#    <Element 'population' at 0x10524f590>]},
#  {'Manchester': [<Element 'population' at 0x10524f890>,
#    <Element 'population' at 0x10524f8d0>,
#    <Element 'population' at 0x10524f910>]},
#  {'Wigan': [<Element 'population' at 0x10524fa50>,
#    <Element 'population' at 0x10524fa90>,
#    <Element 'population' at 0x10524fad0>]},
#  {'Stockport': [<Element 'population' at 0x10524fc10>]},
#  {'Bolton': [<Element 'population' at 0x10524fd50>]},
#  {'Salford': [<Element 'population' at 0x10524fe90>]},
#  {'Oldham': [<Element 'population' at 0x10524ffd0>,
#    <Element 'population' at 0x10525a050>,
#    <Element 'population' at 0x10525a090>]},
#  {'Rochdale': [<Element 'population' at 0x10525a1d0>,
#    <Element 'population' at 0x10525a210>,
#    <Element 'population' at 0x10525a250>]},
#  {'Warrington': [<Element 'population' at 0x10525a390>,
#    <Element 'population' at 0x10525a3d0>,
#    <Element 'population' at 0x10525a410>]},
#  {'Blackpool': [<Element 'population' at 0x10525a550>,
#    <Element 'population' at 0x10525a590>,
#    <Element 'population' at 0x10525a5d0>]},
#  {'Blackburn': [<Element 'population' at 0x10525a750>]},
#  {'Liverpool': [<Element 'population' at 0x10525a890>,
#    <Element 'population' at 0x10525a8d0>,
#    <Element 'population' at 0x10525a910>]},
#  {'Birkenhead': [<Element 'population' at 0x10525aa90>,
#    <Element 'population' at 0x10525aad0>,
#    <Element 'population' at 0x10525ab10>]},
#  {'St Helens': [<Element 'population' at 0x10525ac90>,
#    <Element 'population' at 0x10525acd0>,
#    <Element 'population' at 0x10525ad10>]},
#  {'Preston': [<Element 'population' at 0x10525ae50>]},
#  {'Leeds': [<Element 'population' at 0x1052671d0>,
#    <Element 'population' at 0x105267210>,
#    <Element 'population' at 0x105267250>]},
#  {'Wakefield': [<Element 'population' at 0x105267390>,
#    <Element 'population' at 0x1052673d0>,
#    <Element 'population' at 0x105267410>]},
#  {'Bradford': [<Element 'population' at 0x105267550>,
#    <Element 'population' at 0x105267590>,
#    <Element 'population' at 0x1052675d0>]},
#  {'Huddersfield': [<Element 'population' at 0x105267710>,
#    <Element 'population' at 0x105267750>,
#    <Element 'population' at 0x105267790>]},
#  {'Sheffield': [<Element 'population' at 0x1052678d0>,
#    <Element 'population' at 0x105267910>,
#    <Element 'population' at 0x105267950>]},
#  {'Doncaster': [<Element 'population' at 0x105267a90>,
#    <Element 'population' at 0x105267ad0>,
#    <Element 'population' at 0x105267b10>]},
#  {'Rotherham': [<Element 'population' at 0x105267c50>]},
#  {'York': [<Element 'population' at 0x105267d90>,
#    <Element 'population' at 0x105267dd0>,
#    <Element 'population' at 0x105267e10>]},
#  {'Kingston upon Hull': [<Element 'population' at 0x105267f90>,
#    <Element 'population' at 0x105267fd0>,
#    <Element 'population' at 0x105271050>]},
#  {'Nottingham': [<Element 'population' at 0x105271350>,
#    <Element 'population' at 0x105271390>,
#    <Element 'population' at 0x1052713d0>]},
#  {'Northampton': [<Element 'population' at 0x105271510>,
#    <Element 'population' at 0x105271550>,
#    <Element 'population' at 0x105271590>]},
#  {'Leicester': [<Element 'population' at 0x105271690>,
#    <Element 'population' at 0x1052716d0>,
#    <Element 'population' at 0x105271710>]},
#  {'Derby': [<Element 'population' at 0x105271850>,
#    <Element 'population' at 0x105271890>,
#    <Element 'population' at 0x1052718d0>]},
#  {'Lincoln': [<Element 'population' at 0x105271a10>,
#    <Element 'population' at 0x105271a50>,
#    <Element 'population' at 0x105271a90>]},
#  {'Birmingham': [<Element 'population' at 0x105271e10>,
#    <Element 'population' at 0x105271e50>,
#    <Element 'population' at 0x105271e90>]},
#  {'Coventry': [<Element 'population' at 0x105271fd0>,
#    <Element 'population' at 0x10527e050>,
#    <Element 'population' at 0x10527e090>]},
#  {'Wolverhampton': [<Element 'population' at 0x10527e1d0>]},
#  {'Solihull': [<Element 'population' at 0x10527e310>,
#    <Element 'population' at 0x10527e350>,
#    <Element 'population' at 0x10527e390>]},
#  {'Stoke-on-Trent': [<Element 'population' at 0x10527e4d0>,
#    <Element 'population' at 0x10527e510>,
#    <Element 'population' at 0x10527e550>]},
#  {'Worcester': [<Element 'population' at 0x10527e650>,
#    <Element 'population' at 0x10527e690>,
#    <Element 'population' at 0x10527e6d0>]},
#  {'Sutton Coldfield': [<Element 'population' at 0x10527e850>,
#    <Element 'population' at 0x10527e890>,
#    <Element 'population' at 0x10527e8d0>]},
#  {'Telford': [<Element 'population' at 0x10527ea10>,
#    <Element 'population' at 0x10527ea50>,
#    <Element 'population' at 0x10527ea90>]},
#  {'Cambridge': [<Element 'population' at 0x10527ed90>,
#    <Element 'population' at 0x10527edd0>,
#    <Element 'population' at 0x10527ee10>]},
#  {'Peterborough': [<Element 'population' at 0x10527ef50>,
#    <Element 'population' at 0x10527ef90>,
#    <Element 'population' at 0x10527efd0>]},
#  {'Ipswich': [<Element 'population' at 0x10528a150>,
#    <Element 'population' at 0x10528a190>,
#    <Element 'population' at 0x10528a1d0>]},
#  {'Chelmsford': [<Element 'population' at 0x10528a310>,
#    <Element 'population' at 0x10528a350>,
#    <Element 'population' at 0x10528a390>]},
#  {'Watford': [<Element 'population' at 0x10528a4d0>,
#    <Element 'population' at 0x10528a510>,
#    <Element 'population' at 0x10528a550>]},
#  {'Southend-on-Sea': [<Element 'population' at 0x10528a690>,
#    <Element 'population' at 0x10528a6d0>,
#    <Element 'population' at 0x10528a710>]},
#  {'Basildon': [<Element 'population' at 0x10528a8d0>,
#    <Element 'population' at 0x10528a910>,
#    <Element 'population' at 0x10528a950>]},
#  {'Colchester': [<Element 'population' at 0x10528aa90>,
#    <Element 'population' at 0x10528aad0>,
#    <Element 'population' at 0x10528ab10>]},
#  {'Norwich': [<Element 'population' at 0x10528ac50>,
#    <Element 'population' at 0x10528ac90>,
#    <Element 'population' at 0x10528acd0>]},
#  {'Luton': [<Element 'population' at 0x10528ae10>,
#    <Element 'population' at 0x10528ae50>,
#    <Element 'population' at 0x10528ae90>]},
#  {'London': [<Element 'population' at 0x105296250>,
#    <Element 'population' at 0x105296290>,
#    <Element 'population' at 0x1052962d0>]},
#  {'Southampton': [<Element 'population' at 0x105296610>,
#    <Element 'population' at 0x105296650>,
#    <Element 'population' at 0x105296690>]},
#  {'Portsmouth': [<Element 'population' at 0x105296810>]},
#  {'Basingstoke': [<Element 'population' at 0x105296990>,
#    <Element 'population' at 0x1052969d0>,
#    <Element 'population' at 0x105296a10>]},
#  {'Milton Keynes': [<Element 'population' at 0x105296b50>,
#    <Element 'population' at 0x105296b90>,
#    <Element 'population' at 0x105296bd0>]},
#  {'High Wycombe': [<Element 'population' at 0x105296d10>,
#    <Element 'population' at 0x105296d50>,
#    <Element 'population' at 0x105296d90>]},
#  {'Brighton and Hove': [<Element 'population' at 0x105296ed0>,
#    <Element 'population' at 0x105296f10>,
#    <Element 'population' at 0x105296f50>]},
#  {'Maidstone': [<Element 'population' at 0x1052a3110>]},
#  {'Oxford': [<Element 'population' at 0x1052a3250>,
#    <Element 'population' at 0x1052a3290>,
#    <Element 'population' at 0x1052a32d0>]},
#  {'Reading': [<Element 'population' at 0x1052a3450>,
#    <Element 'population' at 0x1052a3490>]},
#  {'Slough': [<Element 'population' at 0x1052a3610>,
#    <Element 'population' at 0x1052a3650>,
#    <Element 'population' at 0x1052a3690>]},
#  {'Eastbourne': [<Element 'population' at 0x1052a3790>,
#    <Element 'population' at 0x1052a37d0>,
#    <Element 'population' at 0x1052a3810>]},
#  {'Gillingham': [<Element 'population' at 0x1052a3950>,
#    <Element 'population' at 0x1052a3990>,
#    <Element 'population' at 0x1052a39d0>]},
#  {'Crawley': [<Element 'population' at 0x1052a3b10>,
#    <Element 'population' at 0x1052a3b50>,
#    <Element 'population' at 0x1052a3b90>]},
#  {'Worthing': [<Element 'population' at 0x1052a3cd0>]},
#  {'Woking': [<Element 'population' at 0x1052a3e50>,
#    <Element 'population' at 0x1052a3e90>,
#    <Element 'population' at 0x1052a3ed0>]},
#  {'Bristol': [<Element 'population' at 0x1052ae210>,
#    <Element 'population' at 0x1052ae250>,
#    <Element 'population' at 0x1052ae290>]},
#  {'Plymouth': [<Element 'population' at 0x1052ae3d0>]},
#  {'Exeter': [<Element 'population' at 0x1052ae550>,
#    <Element 'population' at 0x1052ae590>,
#    <Element 'population' at 0x1052ae5d0>]},
#  {'Bournemouth': [<Element 'population' at 0x1052ae710>,
#    <Element 'population' at 0x1052ae750>,
#    <Element 'population' at 0x1052ae790>]},
#  {'Poole': [<Element 'population' at 0x1052ae910>,
#    <Element 'population' at 0x1052ae950>,
#    <Element 'population' at 0x1052ae990>]},
#  {'Cheltenham': [<Element 'population' at 0x1052aeb10>,
#    <Element 'population' at 0x1052aeb50>,
#    <Element 'population' at 0x1052aeb90>]},
#  {'Gloucester': [<Element 'population' at 0x1052aec90>,
#    <Element 'population' at 0x1052aecd0>,
#    <Element 'population' at 0x1052aed10>]},
#  {'Swindon': [<Element 'population' at 0x1052aee50>,
#    <Element 'population' at 0x1052aee90>,
#    <Element 'population' at 0x1052aeed0>]},
#  {'Edinburgh': [<Element 'population' at 0x1052ba2d0>,
#    <Element 'population' at 0x1052ba310>,
#    <Element 'population' at 0x1052ba350>]},
#  {'Glasgow': [<Element 'population' at 0x1052ba550>,
#    <Element 'population' at 0x1052ba590>]},
#  {'Aberdeen': [<Element 'population' at 0x1052ba6d0>,
#    <Element 'population' at 0x1052ba710>,
#    <Element 'population' at 0x1052ba750>]},
#  {'Dundee': [<Element 'population' at 0x1052ba8d0>,
#    <Element 'population' at 0x1052ba910>]},
#  {'Kirkwall': [<Element 'population' at 0x1052bab10>]},
#  {'Lerwick': [<Element 'population' at 0x1052bad50>]},
#  {'Cardiff': [<Element 'population' at 0x1052c6190>,
#    <Element 'population' at 0x1052c61d0>,
#    <Element 'population' at 0x1052c6210>]},
#  {'Swansea': [<Element 'population' at 0x1052c6390>,
#    <Element 'population' at 0x1052c63d0>,
#    <Element 'population' at 0x1052c6410>]},
#  {'Newport': [<Element 'population' at 0x1052c6590>,
#    <Element 'population' at 0x1052c65d0>,
#    <Element 'population' at 0x1052c6610>]},
#  {'Belfast': [<Element 'population' at 0x1052c69d0>,
#    <Element 'population' at 0x1052c6a10>,
#    <Element 'population' at 0x1052c6a50>]},
#  {'Kabul': [<Element 'population' at 0x1052d35d0>,
#    <Element 'population' at 0x1052d3610>]},
#  {'Herat': [<Element 'population' at 0x1052d3710>]},
#  {'Kandahar': [<Element 'population' at 0x1052d3810>]},
#  {'Mazar-i-Sharif': [<Element 'population' at 0x1052d3910>]},
#  {'Hefei': [<Element 'population' at 0x1052e1710>,
#    <Element 'population' at 0x1052e1750>,
#    <Element 'population' at 0x1052e1790>,
#    <Element 'population' at 0x1052e17d0>]},
#  {'Huainan': [<Element 'population' at 0x1052e1890>]},
#  {'Bengbu': [<Element 'population' at 0x1052e1950>]},
#  {'Wuhu': [<Element 'population' at 0x1052e1a10>]},
#  {'Huaibei': [<Element 'population' at 0x1052e1b10>]},
#  {'Maanshan': [<Element 'population' at 0x1052e1bd0>]},
#  {'Anqing': [<Element 'population' at 0x1052e1cd0>]},
#  {'Tongling': [<Element 'population' at 0x1052e1dd0>]},
#  {'Fuyang': [<Element 'population' at 0x1052e1ed0>]},
#  {'Luan': [<Element 'population' at 0x1052e1f90>]},
#  {'Chuxian': [<Element 'population' at 0x1052ee090>]},
#  {'Chaoxian': [<Element 'population' at 0x1052ee150>]},
#  {'Xuancheng': [<Element 'population' at 0x1052ee210>]},
#  {'Fuzhou': [<Element 'population' at 0x1052ee5d0>,
#    <Element 'population' at 0x1052ee610>,
#    <Element 'population' at 0x1052ee650>]},
#  {'Xiamen': [<Element 'population' at 0x1052ee790>,
#    <Element 'population' at 0x1052ee7d0>,
#    <Element 'population' at 0x1052ee810>]},
#  {'Nanping': [<Element 'population' at 0x1052ee910>]},
#  {'Quanzhou': [<Element 'population' at 0x1052ee9d0>]},
#  {'Zhangzhou': [<Element 'population' at 0x1052eea90>]},
#  {'Sanming': [<Element 'population' at 0x1052eeb50>]},
#  {'Longyan': [<Element 'population' at 0x1052eec10>]},
#  {'Yongan': [<Element 'population' at 0x1052eecd0>]},
#  {'Lanzhou': [<Element 'population' at 0x1052fb110>,
#    <Element 'population' at 0x1052fb150>,
#    <Element 'population' at 0x1052fb190>,
#    <Element 'population' at 0x1052fb1d0>]},
#  {'Tianshui': [<Element 'population' at 0x1052fb2d0>]},
#  {'Baiyin': [<Element 'population' at 0x1052fb390>]},
#  {'Wuwei': [<Element 'population' at 0x1052fb450>]},
#  {'Yumen': [<Element 'population' at 0x1052fb510>]},
#  {'Guangzhou': [<Element 'population' at 0x1052fb8d0>,
#    <Element 'population' at 0x1052fb910>,
#    <Element 'population' at 0x1052fb950>,
#    <Element 'population' at 0x1052fb990>]},
#  {'Shantou': [<Element 'population' at 0x1052fba90>,
#    <Element 'population' at 0x1052fbad0>,
#    <Element 'population' at 0x1052fbb10>]},
#  {'Zhanjiang': [<Element 'population' at 0x1052fbc10>]},
#  {'Shenzhen': [<Element 'population' at 0x1052fbdd0>,
#    <Element 'population' at 0x1052fbe10>,
#    <Element 'population' at 0x1052fbe50>]},
#  {'Shaoguan': [<Element 'population' at 0x1052fbf10>]},
#  {'Chaozhou': [<Element 'population' at 0x1052fbfd0>]},
#  {'Dongguan': [<Element 'population' at 0x105309110>,
#    <Element 'population' at 0x105309150>,
#    <Element 'population' at 0x105309190>]},
#  {'Foshan': [<Element 'population' at 0x105309290>,
#    <Element 'population' at 0x1053092d0>,
#    <Element 'population' at 0x105309310>]},
#  {'Zhongshan': [<Element 'population' at 0x105309410>,
#    <Element 'population' at 0x105309450>,
#    <Element 'population' at 0x105309490>]},
#  {'Jiangmen': [<Element 'population' at 0x105309550>]},
#  {'Yangjiang': [<Element 'population' at 0x105309610>]},
#  {'Zhaoqing': [<Element 'population' at 0x1053096d0>]},
#  {'Maoming': [<Element 'population' at 0x105309790>]},
#  {'Zhuhai': [<Element 'population' at 0x105309850>]},
#  {'Huizhou': [<Element 'population' at 0x105309950>,
#    <Element 'population' at 0x105309990>,
#    <Element 'population' at 0x1053099d0>]},
#  {'Meixian': [<Element 'population' at 0x105309a90>]},
#  {'Heyuan': [<Element 'population' at 0x105309b50>]},
#  {'Shanwei': [<Element 'population' at 0x105309c10>]},
#  {'Guiyang': [<Element 'population' at 0x105317050>,
#    <Element 'population' at 0x105317090>,
#    <Element 'population' at 0x1053170d0>,
#    <Element 'population' at 0x105317110>]},
#  {'Liupanshui': [<Element 'population' at 0x1053171d0>]},
#  {'Zunyi': [<Element 'population' at 0x105317290>]},
#  {'Anshun': [<Element 'population' at 0x105317350>]},
#  {'Duyun': [<Element 'population' at 0x105317410>]},
#  {'Kaili': [<Element 'population' at 0x1053174d0>]},
#  {'Haikou': [<Element 'population' at 0x105317850>]},
#  {'Sanya': [<Element 'population' at 0x105317990>]},
#  ...]

# %%
final_popu_list = []

for val in popu_list:
    for k in val.keys():
        final_popu_list.append([k, val[k][-1].text])

# %%
final_popu_list
# Out:
# [['Tirana', '418495'],
#  [u'Shkod\xebr', '77075'],
#  [u'Durr\xebs', '113249'],
#  [u'Vlor\xeb', '79513'],
#  ['Elbasan', '78703'],
#  [u'Kor\xe7\xeb', '51152'],
#  ['Kavala', '58790'],
#  ['Athina', '664046'],
#  ['Peiraias', '163688'],
#  ['Peristeri', '139981'],
#  ['Acharnes', '106943'],
#  ['Patra', '213984'],
#  ['Kerkyra', '102071'],
#  ['Ioannina', '112486'],
#  ['Thessaloniki', '325182'],
#  ['Iraklio', '173993'],
#  ['Chania', '108642'],
#  ['Rhodes', '115490'],
#  ['Lamia', '75315'],
#  ['Chalkida', '102223'],
#  ['Larissa', '162591'],
#  ['Volos', '144449'],
#  ['Karyes', '233'],
#  ['Skopje', '514967'],
#  ['Kumanovo', '107745'],
#  ['Beograd', '1639121'],
#  ['Novi Sad', '335701'],
#  [u'Ni\u0161', '257867'],
#  ['Podgorica', '150977'],
#  ['Prishtine', '198214'],
#  ['Andorra la Vella', '22256'],
#  ['Strasbourg', '272222'],
#  ['Mulhouse', '110351'],
#  ['Bordeaux', '239399'],
#  ['Clermont-Ferrand', '140957'],
#  ['Caen', '108793'],
#  ['Rennes', '208033'],
#  ['Brest', '140547'],
#  ['Dijon', '151672'],
#  [u'Orl\xe9ans', '114185'],
#  ['Tours', '134633'],
#  ['Reims', '180752'],
#  ['Ajaccio', '66245'],
#  [u'Besan\xe7on', '115879'],
#  ['Rouen', '111553'],
#  ['Le Havre', '174156'],
#  ['Paris', '2249975'],
#  ['Boulogne-Billancourt', '116220'],
#  ['Argenteuil', '104282'],
#  ['Montreuil', '103068'],
#  ['Saint-Paul', '103916'],
#  ['Montpellier', '264538'],
#  [u'N\xeemes', '144940'],
#  ['Perpignan', '118238'],
#  ['Limoges', '137758'],
#  ['Metz', '119962'],
#  ['Nancy', '105382'],
#  ['Toulouse', '447340'],
#  ['Lille', '227533'],
#  ['Nantes', '287845'],
#  ['Angers', '148803'],
#  ['Le Mans', '143240'],
#  ['Amiens', '133327'],
#  ['Poitiers', '87646'],
#  ['Marseille', '850636'],
#  ['Nice', '344064'],
#  ['Toulon', '163974'],
#  ['Aix-en-Provence', '140684'],
#  ['Lyon', '491268'],
#  ['Grenoble', '157424'],
#  [u'Saint-\xc9tienne', '170049'],
#  ['Villeurbanne', '145034'],
#  ['Sevilla', '698042'],
#  [u'Almer\xeda', '189680'],
#  [u'C\xe1diz', '124014'],
#  [u'C\xf3rdoba', '328326'],
#  ['Granada', '241003'],
#  ['Huelva', '147808'],
#  [u'M\xe1laga', '561435'],
#  ['Jerez de la Frontera', '211784'],
#  [u'Ja\xe9n', '116469'],
#  ['Algeciras', '117695'],
#  ['Marbella', '135124'],
#  ['Dos Hermanas', '128433'],
#  ['Zaragoza', '678115'],
#  ['Oviedo', '225005'],
#  [u'Gij\xf3n', '276969'],
#  ['Palma de Mallorca', '402044'],
#  ['Vitoria-Gasteiz', '240753'],
#  ['Bilbao', '351356'],
#  ['Barakaldo', '100064'],
#  ['Donostia', '185512'],
#  ['Santa Cruz de Tenerife', '204476'],
#  [u'San Crist\xf3bal de La Laguna', '152025'],
#  ['Las Palmas de Gran Canaria', '381271'],
#  ['Telde', '101080'],
#  ['Santander', '178095'],
#  ['Valladolid', '311682'],
#  ['Burgos', '178864'],
#  [u'Le\xf3n', '131411'],
#  ['Salamanca', '151658'],
#  ['Albacete', '171999'],
#  ['Barcelona', '1611013'],
#  ['Lleida', '137283'],
#  ['Tarragona', '133223'],
#  ['Reus', '106849'],
#  ['Hospitalet de Llobregat', '256509'],
#  ['Badalona', '219241'],
#  ['Sabadell', '206949'],
#  ['Terrassa', '214406'],
#  ['Santa Coloma de Gramenet', '119391'],
#  [u'Matar\xf3', '123367'],
#  ['Badajoz', '151214'],
#  [u'A Coru\xf1a', '245053'],
#  ['Vigo', '295623'],
#  ['Ourense', '107314'],
#  ['Madrid', '3198645'],
#  [u'M\xf3stoles', '203493'],
#  [u'Legan\xe9s', '185758'],
#  [u'Alcal\xe1 de Henares', '200505'],
#  ['Fuenlabrada', '196986'],
#  ['Getafe', '168642'],
#  [u'Alcorc\xf3n', '167217'],
#  [u'Torrej\xf3n de Ardoz', '123213'],
#  ['Parla', '122045'],
#  ['Alcobendas', '110351'],
#  ['Murcia', '437667'],
#  ['Cartagena', '215757'],
#  ['Pamplona', '195943'],
#  [u'Logro\xf1o', '152698'],
#  ['Valencia', '792054'],
#  ['Alicante', '329325'],
#  ['Elche', '227417'],
#  [u'Castell\xf3n de la Plana', '176298'],
#  ['Eisenstadt', '13485'],
#  ['Klagenfurt', '96531'],
#  ['Villach', '59942'],
#  ['Wien', '1761738'],
#  ['Linz', '193511'],
#  ['Wels', '59239'],
#  ['Innsbruck', '124386'],
#  ['Graz', '269211'],
#  ['Salzburg', '146676'],
#  [u'St. P\xf6lten', '52100'],
#  ['Praha', '1289556'],
#  [u'\u010cesk\xe9 Bud\u011bjovice', '95589'],
#  ['Brno', '404820'],
#  ['Karlovy Vary', '53310'],
#  ['Jihlava', '51162'],
#  [u'Hradec Kr\xe1lov\xe9', '95594'],
#  ['Liberec', '104973'],
#  ['Ostrava', '311508'],
#  ['Olomouc', '101954'],
#  ['Pardubice', '90844'],
#  [u'Plze\u0148', '171346'],
#  [u'\xdast\xed nad Labem', '98596'],
#  [u'Zl\xedn', '77137'],
#  ['Stuttgart', '585890'],
#  ['Mannheim', '290117'],
#  ['Karlsruhe', '289173'],
#  ['Freiburg', '209628'],
#  ['Heidelberg', '146751'],
#  ['Heilbronn', '116059'],
#  ['Pforzheim', '114411'],
#  ['Ulm', '116761'],
#  ['Reutlingen', '109799'],
#  [u'M\xfcnchen', '1348335'],
#  [u'N\xfcrnberg', '486314'],
#  ['Augsburg', '267767'],
#  [u'W\xfcrzburg', '124297'],
#  ['Regensburg', '135403'],
#  ['Ingolstadt', '124927'],
#  [u'F\xfcrth', '115613'],
#  ['Erlangen', '103719'],
#  ['Berlin', '3292365'],
#  ['Potsdam', '156021'],
#  ['Cottbus', '99984'],
#  ['Bremen', '542707'],
#  ['Bremerhaven', '108156'],
#  ['Hamburg', '1706696'],
#  ['Wiesbaden', '269121'],
#  ['Frankfurt am Main', '667925'],
#  ['Kassel', '190765'],
#  ['Darmstadt', '143499'],
#  ['Offenbach am Main', '113443'],
#  ['Schwerin', '91293'],
#  ['Rostock', '200265'],
#  ['Hannover', '506416'],
#  ['Braunschweig', '242537'],
#  [u'Osnabr\xfcck', '153699'],
#  ['Oldenburg', '157267'],
#  [u'G\xf6ttingen', '115843'],
#  ['Wolfsburg', '119984'],
#  ['Salzgitter', '98895'],
#  ['Hildesheim', '99554'],
#  [u'D\xfcsseldorf', '586291'],
#  [u'K\xf6ln', '1005775'],
#  ['Essen', '566201'],
#  ['Dortmund', '571143'],
#  ['Duisburg', '488468'],
#  ['Bochum', '362286'],
#  ['Wuppertal', '342661'],
#  ['Bielefeld', '326870'],
#  ['Gelsenkirchen', '258766'],
#  ['Bonn', '305765'],
#  [u'M\xf6nchengladbach', '255188'],
#  [u'M\xfcnster', '289576'],
#  ['Krefeld', '222247'],
#  ['Aachen', '236420'],
#  ['Oberhausen', '210216'],
#  ['Hagen', '187944'],
#  ['Hamm', '176037'],
#  ['Herne', '155160'],
#  [u'M\xfclheim an der Ruhr', '166865'],
#  ['Solingen', '155265'],
#  ['Leverkusen', '158984'],
#  ['Neuss', '150568'],
#  ['Paderborn', '142365'],
#  ['Recklinghausen', '115958'],
#  ['Remscheid', '110708'],
#  ['Bottrop', '117311'],
#  ['Siegen', '99187'],
#  ['Moers', '104009'],
#  ['Witten', '96382'],
#  ['Bergisch Gladbach', '108878'],
#  ['Mainz', '200344'],
#  ['Ludwigshafen', '157584'],
#  ['Koblenz', '107825'],
#  ['Kaiserslautern', '96340'],
#  ['Trier', '105671'],
#  [u'Saarbr\xfccken', '175853'],
#  ['Dresden', '512354'],
#  ['Leipzig', '502979'],
#  ['Chemnitz', '240253'],
#  ['Zwickau', '93081'],
#  ['Magdeburg', '228144'],
#  ['Halle', '229153'],
#  ['Kiel', '235782'],
#  [u'L\xfcbeck', '210305'],
#  ['Erfurt', '200868'],
#  ['Gera', '96067'],
#  ['Jena', '105739'],
#  [u'P\xe9cs', '156049'],
#  [u'Kecskem\xe9t', '111411'],
#  [u'B\xe9k\xe9scsaba', '62050'],
#  ['Miskolc', '167754'],
#  ['Szeged', '168048'],
#  [u'Sz\xe9kesfeh\xe9rv\xe1r', '100570'],
#  [u'Gy\u0151r', '129527'],
#  ['Debrecen', '211320'],
#  ['Eger', '56569'],
#  [u'Tatab\xe1nya', '67753'],
#  [u'Kaposv\xe1r', '66245'],
#  [u'Ny\xedregyh\xe1za', '119746'],
#  ['Szolnok', '72953'],
#  ['Szombathely', '78884'],
#  [u'Veszpr\xe9m', '61721'],
#  ['Zalaegerszeg', '59499'],
#  ['Budapest', '1729040'],
#  ['Novara', '101952'],
#  ['Torino', '872367'],
#  [u'B\xe9rgamo', '115349'],
#  [u'Br\xe9scia', '189902'],
#  ['Milano', '1242123'],
#  ['Monza', '119856'],
#  ['Bolzano', '102575'],
#  ['Trento', '114198'],
#  [u'P\xe1dova', '206192'],
#  ['Verona', '252520'],
#  ['Vicenza', '111500'],
#  [u'Ven\xe9zia', '261362'],
#  ['Trieste', '202123'],
#  ['La Spezia', '92659'],
#  [u'G\xe9nova', '586180'],
#  ['Bologna', '371337'],
#  ['Ferrara', '132545'],
#  [u'Forl\xed', '116434'],
#  [u'M\xf3dena', '179149'],
#  ['Parma', '175895'],
#  ['Piacenza', '100311'],
#  ['Ravenna', '153740'],
#  [u"R\xe9ggio nell'Emilia", '162082'],
#  [u'R\xedmini', '139601'],
#  ['Livorno', '157052'],
#  ['Pisa', '85858'],
#  ['Firenze', '358079'],
#  ['Prato', '185456'],
#  [u'Per\xfagia', '162449'],
#  ['Terni', '109193'],
#  ['Ancona', '100497'],
#  ['Roma', '2617175'],
#  ['Latina', '117892'],
#  ['Pescara', '117166'],
#  ['Salerno', '132608'],
#  [u'N\xe1poli', '962003'],
#  ['Torre del Greco', '85922'],
#  ['Giugliano in Campania', '108793'],
#  ['Bari', '315933'],
#  [u'F\xf3ggia', '147036'],
#  ['Lecce', '89916'],
#  ['Andria', '100052'],
#  [u'T\xe1ranto', '200154'],
#  ['Catanzaro', '89364'],
#  ['Cosenza', '69484'],
#  [u'R\xe9ggio di Calabria', '180817'],
#  ['Palermo', '657561'],
#  ['Messina', '243262'],
#  [u'Cat\xe1nia', '293902'],
#  ['Siracusa', '118385'],
#  [u'C\xe1gliari', '149883'],
#  [u'S\xe1ssari', '123782'],
#  ['Vaduz', '5241'],
#  ['Bratislava', '411228'],
#  [u'Bansk\xe1 Bystrica', '80003'],
#  [u'\u017dilina', '81494'],
#  [u'Ko\u0161ice', '240433'],
#  [u'Pre\u0161ov', '91782'],
#  ['Nitra', '78916'],
#  [u'Tren\u010d\xedn', '55877'],
#  ['Trnava', '66358'],
#  ['Ljubljana', '282994'],
#  ['Maribor', '111374'],
#  ['Basel', '167386'],
#  ['Bern', '128848'],
#  ['Biel', '53031'],
#  [u'Gen\xe8ve', '191557'],
#  ['Luzern', '80501'],
#  ['Sankt Gallen', '74581'],
#  ['Lugano', '62792'],
#  ['Lausanne', '132788'],
#  [u'Z\xfcrich', '384786'],
#  ['Winterthur', '105676'],
#  ['Brest', '309764'],
#  ['Vitebsk', '347928'],
#  ['Gomel', '482652'],
#  ['Grodno', '327540'],
#  ['Mogilev', '358279'],
#  ['Bobruysk', '215092'],
#  ['Minsk', '1836808'],
#  [u'R\u012bga', '696618'],
#  ['Vilnius', '538747'],
#  ['Kaunas', '307498'],
#  ['Klaipeda', '158891'],
#  [u'Wroc\u0142aw', '631377'],
#  ['Legnica', '102708'],
#  [u'Wa\u0142brzych', '119216'],
#  ['Bydgoszcz', '362286'],
#  [u'Toru\u0144', '204847'],
#  ['Grudziadz', '98726'],
#  [u'W\u0142oc\u0142awek', '115982'],
#  ['Lublin', '348120'],
#  [u'Zielona G\xf3ra', '119182'],
#  [u'Gorz\xf3w Wielkopolski', '124470'],
#  [u'\u0141\xf3d\u017a', '722022'],
#  [u'Krak\xf3w', '759131'],
#  [u'Tarn\xf3w', '113188'],
#  ['Warszawa', '1711324'],
#  [u'P\u0142ock', '124048'],
#  ['Radom', '220062'],
#  ['Opole', '122120'],
#  [u'Rzesz\xf3w', '180776'],
#  [u'Bia\u0142ystok', '294675'],
#  [u'Gda\u0144sk', '460354'],
#  ['Gdynia', '248574'],
#  ['Katowice', '308269'],
#  ['Jastrzebie Zdroj', '92465'],
#  ['Sosnowiec', '214488'],
#  [u'D\u0105browa G\xf3rnicza', '125063'],
#  ['Bytom', '175377'],
#  ['Gliwice', '186347'],
#  ['Zabrze', '179861'],
#  ['Tychy', '129087'],
#  [u'Ruda \u015al\u0105ska', '142672'],
#  ['Rybnik', '140863'],
#  [u'Chorz\xf3w', '111314'],
#  [u'Cz\u0119stochowa', '235156'],
#  [u'Bielsko-Bia\u0142a', '174291'],
#  ['Kielce', '201363'],
#  ['Olsztyn', '175482'],
#  [u'Elbl\u0105g', '123977'],
#  [u'Pozna\u0144', '552393'],
#  ['Kalisz', '104867'],
#  ['Szczecin', '409211'],
#  ['Koszalin', '109183'],
#  ['Cherkasy', '286163'],
#  ['Chernihiv', '296723'],
#  ['Chernivtsi', '255929'],
#  [u'Dnipropetrovs\xb4k', '999577'],
#  ['Kryvyi Rih', '660203'],
#  [u'Dniprodzerzhyns\xb4k', '242646'],
#  [u'Nikopol\xb4', '120000'],
#  [u'Donets\xb4k', '955041'],
#  [u'Mariupol\xb4', '464457'],
#  [u'Maki\xefvka', '356118'],
#  ['Horlivka', '258879'],
#  [u'Kramators\xb4k', '165469'],
#  [u'Ivano-Frankivs\xb4k', '224660'],
#  ['Kharkiv', '1441362'],
#  ['Kherson', '300666'],
#  [u'Khmel\xb4nyts\xb4kyi', '263703'],
#  ['Prypjat', '0'],
#  ['Kirovohrad', '234919'],
#  [u'Luhans\xb4k', '427187'],
#  [u'L\xb4viv', '729842'],
#  [u'Mykola\xefv', '497032'],
#  ['Odesa', '1008162'],
#  ['Poltava', '297589'],
#  ['Kremenchuk', '226434'],
#  ['Rivne', '250174'],
#  ['Sumy', '269663'],
#  [u'Ternopil\xb4', '217300'],
#  ['Vinnytsia', '370814'],
#  [u'Luts\xb4k', '213063'],
#  ['Uzhhorod', '116556'],
#  ['Zaporizhzhia', '772627'],
#  [u'Melitopol\xb4', '156885'],
#  ['Zhytomyr', '271895'],
#  [u'Simferopol\xb4', '335582'],
#  ['Kerch', '145845'],
#  [u'Ky\xefv', '2814258'],
#  ['Bila Tserkva', '210551'],
#  [u'Sevastopol\xb4', '340559'],
#  ['Petrozavodsk', '268946'],
#  ['Syktyvkar', '235006'],
#  ['Ukhta', '99591'],
#  ['Vorkuta', '70548'],
#  ['Arkhangelsk', '350985'],
#  ['Severodvinsk', '192353'],
#  ['Vologda', '306487'],
#  ['Cherepovets', '315738'],
#  ['Murmansk', '302468'],
#  ['Kaliningrad', '441376'],
#  ['Sankt Peterburg', '5028000'],
#  ['Velikij Novgorod', '218717'],
#  ['Pskov', '203279'],
#  ['Bryansk', '410837'],
#  ['Vladimir', '347930'],
#  ['Kovrov', '145214'],
#  ['Murom', '116075'],
#  ['Ivanovo', '409075'],
#  ['Kaluga', '331351'],
#  ['Obninsk', '104739'],
#  ['Kostroma', '271445'],
#  ['Moskva', '11979529'],
#  ["Podol'sk", '187961'],
#  [u'\u017deleznodoro\u017enyj', '131257'],
#  ['Krasnogorsk', '116896'],
#  ["L'ubercy", '172525'],
#  ['Kolomna', '144589'],
#  [u'Myti\u0161\u010di', '173160'],
#  ["Elektrostal'", '155196'],
#  ['Serpuchov', '127041'],
#  [u'Bala\u0161icha', '215494'],
#  ['Chimki', '207425'],
#  ['Odincovo', '138930'],
#  ['Orechovo-Zujevo', '120670'],
#  ['Noginsk', '100072'],
#  [u'\u0160\u010d\xeblkovo', '110411'],
#  ['Sergijev Posad', '111179'],
#  [u'Korol\xebv', '183402'],
#  [u'\u017dukovskij', '104736'],
#  [u'Pu\u0161kino', '102874'],
#  ['Orel', '318136'],
#  ['Ryazan', '527905'],
#  ['Smolensk', '330970'],
#  ['Tver', '408877'],
#  ['Tula', '493813'],
#  ['Novomoskovsk', '131386'],
#  ['Yaroslavl', '599169'],
#  ['Rybinsk', '200771'],
#  ['Yoshkar-Ola', '257015'],
#  ['Saransk', '298287'],
#  ['Cheboksary', '464940'],
#  [u'Novo\u010deboksarsk', '124097'],
#  ['Kirov', '483176'],
#  ['Nizhnii Novgorod', '1259921'],
#  [u'Dzer\u017einsk', '240742'],
#  ['Arzamas', '106362'],
#  ['Belgorod', '373528'],
#  ['Staryj Oskol', '221085'],
#  ['Voronezh', '1003638'],
#  ['Kursk', '428741'],
#  ['Lipetsk', '509098'],
#  ['Jelec', '108404'],
#  ['Tambov', '281834'],
#  ['Elista', '103749'],
#  ['Kazan', '1176187'],
#  ['Naberezhnye Tchelny', '519025'],
#  [u'Ni\u017enekamsk', '234044'],
#  ["Al'metjevsk", '146393'],
#  ['Astrakhan', '527345'],
#  ['Volgograd', '1018790'],
#  ['Volzhsky', '327356'],
#  [u'Kamy\u0161in', '119565'],
#  ['Penza', '519900'],
#  ['Samara', '1171598'],
#  ['Tolyatti', '719149'],
#  ["Syzran'", '178750'],
#  [u'Novokujby\u0161evsk', '108438'],
#  ['Saratov', '839755'],
#  ['Balakovo', '199690'],
#  [u"\u0116ngel's", '202419'],
#  ['Ulyanovsk', '615306'],
#  ['Dimitrovgrad', '122580'],
#  ['Rostov-na-Donu', '1103733'],
#  ['Batajsk', '111843'],
#  ['Taganrog', '254783'],
#  [u'\u0160achty', '239987'],
#  [u'Novo\u010derkassk', '168746'],
#  ['Volgodonsk', '170841'],
#  [u'Novo\u0161achtinsk', '111075'],
#  ['Ufa', '1077719'],
#  ['Sterlitamak', '275798'],
#  ['Salavat', '156095'],
#  ["Okt'abr'skij", '109474'],
#  ['Izhevsk', '632913'],
#  ['Sarapul', '101381'],
#  ['Orenburg', '556127'],
#  ['Orsk', '239800'],
#  ['Perm', '1013887'],
#  ['Berezniki', '156466'],
#  ['Majkop', '144249'],
#  ['Makhachkala', '576194'],
#  ['Derbent', '119200'],
#  ['Kaspijsk', '100129'],
#  ['Chasavjurt', '131187'],
#  ["Nazran'", '93335'],
#  [u"Nal'\u010dik", '240203'],
#  [u'\u010cerkessk', '129069'],
#  ['Vladikavkaz', '308285'],
#  ['Grozny', '277414'],
#  ['Krasnodar', '784048'],
#  ['Sochi', '368011'],
#  ['Novorossiysk', '251013'],
#  ['Armavir', '188832'],
#  ['Stavropol', '412116'],
#  ["P'atigorsk", '142511'],
#  ['Nevinnomyssk', '118360'],
#  ['Kislovodsk', '128553'],
#  ['Jessentuki', '100996'],
#  ['Neftekamsk', '121733'],
#  ['Kurgan', '325565'],
#  ['Yekaterinburg', '1396074'],
#  ['Nizhny Tagil', '358378'],
#  ["Kamensk-Ural'skij", '174689'],
#  ["Pervoural'sk", '124528'],
#  ['Chelyabinsk', '1156201'],
#  ['Magnitogorsk', '411880'],
#  ['Zlatoust', '174962'],
#  ['Miass', '151751'],
#  ['Kopejsk', '137601'],
#  ['Gorno Altaysk', '56933'],
#  ['Barnaul', '629681'],
#  ['Bijsk', '210115'],
#  ['Rubcovsk', '147002'],
#  ['Kemerovo', '540095'],
#  ['Novokuznetsk', '549182'],
#  ['Prokopjevsk', '210130'],
#  ['Novosibirsk', '1523801'],
#  ['Omsk', '1160670'],
#  ['Tomsk', '547989'],
#  ['Seversk', '108590'],
#  ['Tyumen', '634171'],
#  ['Ulan-Ude', '416079'],
#  ['Kyzyl', '109918'],
#  ['Abakan', '165214'],
#  ['Krasnoyarsk', '1016385'],
#  ["Noril'sk", '175365'],
#  [u'A\u010dinsk', '109155'],
#  ['Irkutsk', '606137'],
#  ['Angarsk', '233567'],
#  ['Bratsk', '246319'],
#  ['Chita', '331346'],
#  ['Yakutsk', '286456'],
#  ['Birobidzhan', '75413'],
#  ['Anadyr', '13045'],
#  ['Vladivostok', '600378'],
#  ['Nachodka', '159719'],
#  ['Ussurijsk', '158004'],
#  ['Khabarovsk', '593636'],
#  ['Komsomolsk-na-Amure', '257891'],
#  [u'Blagove\u0161\u010densk', '214390'],
#  [u'Petropavlovsk-Kam\u010datskij', '179780'],
#  ['Magadan', '95982'],
#  ['Okhotsk', '4215'],
#  [u'Ju\u017eno-Sachalinsk', '181728'],
#  ['Khanty Mansijsk', '80151'],
#  ['Surgut', '325511'],
#  ['Nizhnevartovsk', '263228'],
#  ['Neftejugansk', '122855'],
#  ['Salekhard', '42544'],
#  ["Nojabr'sk", '110620'],
#  ['Novyj Urengoj', '104107'],
#  ['Bruxelles', '168576'],
#  ['Schaerbeek', '130587'],
#  ['Molenbeek-Saint-Jean', '94653'],
#  ['Anderlecht', '113462'],
#  ['Antwerpen', '507911'],
#  ['Gent', '248813'],
#  ['Charleroi', '203753'],
#  ['Mons', '93941'],
#  [u'Li\xe8ge', '195931'],
#  ['Hasselt', '75579'],
#  ['Arlon', '28759'],
#  ['Namur', '110500'],
#  ['Brugge', '117577'],
#  ['Leuven', '97692'],
#  ['Luxembourg', '99852'],
#  ['Groningen', '198023'],
#  ['Leeuwarden', '108145'],
#  ['Enschede', '158494'],
#  ['Zwolle', '123440'],
#  ['Lelystad', '76252'],
#  ['Almere', '196244'],
#  ['Arnhem', '150989'],
#  ['Nijmegen', '168810'],
#  ['Apeldoorn', '157540'],
#  ['Utrecht', '330081'],
#  ['Amersfoort', '151270'],
#  ['Amsterdam', '812895'],
#  ['Haarlem', '155361'],
#  ['Zaanstad', '151058'],
#  ['Hilversum', '86738'],
#  ['Den Haag', '509623'],
#  ['Rotterdam', '619180'],
#  ['Dordrecht', '118780'],
#  ['Leiden', '121387'],
#  ["'s-Hertogenbosch", '143822'],
#  ['Eindhoven', '221279'],
#  ['Tilburg', '210283'],
#  ['Breda', '180263'],
#  ['Maastricht', '122243'],
#  ['Heerlen', '88139'],
#  ['Sittard-Geleen', '93726'],
#  ['Sarajevo', '291422'],
#  ['Tuzla', '120441'],
#  ['Zenica', '115134'],
#  ['Mostar', '113169'],
#  ['Banja Luka', '199191'],
#  ['Bijeljina', '114663'],
#  [u'Br\u010dko', '93028'],
#  ['Zagreb', '686568'],
#  ['Split', '165893'],
#  ['Rijeka', '127498'],
#  ['Osijek', '83496'],
#  ['Zadar', '70674'],
#  ['Sofia', '1270284'],
#  ['Plovdiv', '331796'],
#  ['Varna', '330486'],
#  ['Burgas', '197301'],
#  ['Ruse', '146609'],
#  ['Stara Zagora', '136363'],
#  ['Arad', '159074'],
#  [u'Pite\u015fti', '155383'],
#  [u'Bac\u0103u', '144307'],
#  ['Oradea', '196367'],
#  [u'Boto\u015fani', '106847'],
#  [u'Br\u0103ila', '180302'],
#  [u'Bra\u015fov', '253200'],
#  [u'Bucure\u015fti', '1883425'],
#  [u'Buz\u0103u', '115494'],
#  ['Cluj-Napoca', '324576'],
#  [u'Constan\u0163a', '283872'],
#  ['Craiova', '269506'],
#  [u'Gala\u0163i', '249432'],
#  [u'Ia\u015fi', '290422'],
#  ['Baia Mare', '123738'],
#  ['Drobeta-Turnu Severin', '92617'],
#  [u'T\xe2rgu Mure\u015f', '134290'],
#  [u'Piatra-Neam\u0163', '85055'],
#  [u'Ploie\u015fti', '209945'],
#  ['Satu Mare', '102411'],
#  ['Sibiu', '147245'],
#  ['Suceava', '92121'],
#  [u'Timi\u015foara', '319279'],
#  [u'R\xe2mnicu V\xe2lcea', '98776'],
#  ['Adana', '1636229'],
#  ['Adiyaman', '217463'],
#  ['Afyonkarahisar', '186991'],
#  ['Agri', '107839'],
#  ['Aksaray', '186599'],
#  ['Amasya', '91874'],
#  ['Ankara', '4630735'],
#  ['Antalya', '1073794'],
#  ['Aydin', '195951'],
#  ['Balikesir', '267903'],
#  ['Batman', '348963'],
#  ['Bingol', '98424'],
#  ['Bolu', '131264'],
#  ['Bursa', '1734705'],
#  [u'\u0130neg\xf6l', '177617'],
#  ['Canakkale', '111137'],
#  ['Corum', '231146'],
#  ['Denizli', '525497'],
#  ['Diyarbakir', '892713'],
#  ['Edirne', '148474'],
#  ['Elazig', '347857'],
#  ['Erzincan', '96474'],
#  ['Erzurum', '384399'],
#  ['Eskisehir', '659924'],
#  ['Gaziantep', '1438373'],
#  ['Giresun', '100712'],
#  ['Iskenderun', '184833'],
#  ['Hatay', '216960'],
#  ['Mersin', '876958'],
#  ['Tarsus', '245671'],
#  ['Isparta', '198385'],
#  ['Istanbul', '13710512'],
#  ['Izmir', '3401994'],
#  ['Karaman', '141630'],
#  [u'Kahramanmara\u015f', '443575'],
#  ['Kars', '78100'],
#  ['Kastamonu', '96217'],
#  ['Kayseri', '1004276'],
#  ['Kirikkale', '192473'],
#  ['Luleburgaz', '105279'],
#  ['Kirsehir', '114244'],
#  ['Kocaeli', '1527407'],
#  ['Gebze', '290868'],
#  ['Konya', '1107886'],
#  [u'K\xfctahya', '224898'],
#  ['Malatya', '426381'],
#  ['Manisa', '309050'],
#  ['Mardin', '86948'],
#  [u'K\u0131z\u0131ltepe', '147585'],
#  ['Mus', '81764'],
#  ['Nevsehir', '92068'],
#  ['Nigde', '118186'],
#  ['Ordu', '147913'],
#  ['Rize', '104508'],
#  ['Sakarya', '590498'],
#  ['Samsun', '547778'],
#  [u'\u015eanl\u0131urfa', '526247'],
#  ['Siirt', '135350'],
#  ['Sivas', '312587'],
#  ['Tekirdag', '150112'],
#  [u'\xc7orlu', '235354'],
#  ['Tokat', '132437'],
#  ['Trabzon', '243735'],
#  ['Usak', '187886'],
#  ['Van', '370190'],
#  ['Yozgat', '78328'],
#  ['Zonguldak', '109080'],
#  [u'Karab\xfck', '110537'],
#  [u'I\u011fd\u0131r', '82656'],
#  ['Yalova', '102874'],
#  ['Kilis', '85119'],
#  ['Duzce', '135557'],
#  ['Osmaniye', '209255'],
#  ['Aalborg', '104885'],
#  [u'\xc5rhus', '252213'],
#  ['Randers', '61121'],
#  ['Vejle', '51804'],
#  ['Odense', '168798'],
#  ['Esbjerg', '71579'],
#  [u'K\xf8benhavn', '549050'],
#  ['Tallinn', '399340'],
#  ['Tartu', '103284'],
#  [u'T\xf3rshavn', '12245'],
#  ['Mariehamn', '10851'],
#  ['Tampere', '220678'],
#  ['Lahti', '103396'],
#  [u'H\xe4meenlinna', '67803'],
#  ['Kuopio', '106475'],
#  ['Lappeenranta', '72617'],
#  ['Kotka', '54714'],
#  ['Rovaniemi', '61244'],
#  ['Mikkeli', '54633'],
#  [u'Jyv\xe4skyl\xe4', '134862'],
#  ['Joensuu', '74332'],
#  ['Oulu', '194181'],
#  ['Pori', '83457'],
#  ['Turku', '182154'],
#  ['Helsinki', '614535'],
#  ['Espoo', '261654'],
#  ['Vaasa', '66415'],
#  ['Oslo', '623966'],
#  ['Sandvika', '116677'],
#  ['Moss', '24517'],
#  ['Hamar', '15685'],
#  ['Lillehammer', '22118'],
#  ['Drammen', '65473'],
#  ['Tonsberg', '8984'],
#  ['Skien', '53015'],
#  ['Arendal', '12174'],
#  ['Kristiansand', '84476'],
#  ['Stavanger', '129191'],
#  ['Bergen', '267950'],
#  ['Hermannsverk', '706'],
#  ['Molde', '21448'],
#  ['Trondheim', '179692'],
#  ['Steinkjer', '20480'],
#  ['Svolvaer', '4500'],
#  ['Narvik', '18754'],
#  ['Bodoe', '34479'],
#  [u'Troms\xf8', '70358'],
#  ['Hammerfest', '7089'],
#  ['Vadsoe', '5961'],
#  [u'G\xf6teborg', '526089'],
#  ['Vanersborg', '35804'],
#  ['Mariestad', '24255'],
#  [u'Bor\xe5s', '104867'],
#  ['Karlskrona', '59007'],
#  [u'G\xe4vle', '96170'],
#  ['Visby', '20000'],
#  ['Halmstad', '93231'],
#  ['Ostersund', '56662'],
#  [u'J\xf6nk\xf6ping', '129478'],
#  ['Kalmar', '54554'],
#  ['Falun', '51900'],
#  [u'Malm\xf6', '307758'],
#  ['Helsingborg', '132011'],
#  ['Kristianstad', '80507'],
#  ['Lund', '112950'],
#  [u'V\xe4xj\xf6', '84800'],
#  ['Lulea', '66526'],
#  ['Jokkmokk', '6822'],
#  [u'\xd6rebro', '138952'],
#  [u'Link\xf6ping', '148521'],
#  [u'Norrk\xf6ping', '132124'],
#  ['Nykoping', '64199'],
#  ['Eskilstuna', '98765'],
#  ['Stockholm', '881235'],
#  ['Huddinge', '101010'],
#  ['Uppsala', '202625'],
#  ['Karlstad', '86929'],
#  [u'Ume\xe5', '117294'],
#  ['Harnosand', '27287'],
#  [u'V\xe4ster\xe5s', '140499'],
#  ['Monaco', '975'],
#  ['Vatican City', '842'],
#  ['Ceuta', '82376'],
#  ['Melilla', '78476'],
#  ['Reykjavik', '118061'],
#  ['Keflavik', '13862'],
#  ['Hafnarfjordur', '26099'],
#  ['Akureyri', '17490'],
#  ['Dublin', '525383'],
#  ['Cork', '118912'],
#  ['Galway', '75414'],
#  ['Limerick', '56779'],
#  ['San Marino', '4227'],
#  ['Valletta', '5748'],
#  ['Victoria', '6252'],
#  [u'Chi\u015fin\u0103u', '663400'],
#  ['Tiraspol', '148917'],
#  [u'B\u0103l\u0163i', '143300'],
#  ['Aveiro', '53496'],
#  ['Braga', '114003'],
#  ['Coimbra', '118016'],
#  ['Leiria', '50608'],
#  ['Lisboa', '559248'],
#  ['Amadora', '89232'],
#  ['Barreiro', '79042'],
#  ['Almada', '49578'],
#  ['Oporto', '266790'],
#  ['Vila Nova de Gaia', '72576'],
#  [u'Set\xfabal', '91108'],
#  ['Ponta Delgada', '46102'],
#  ['Funchal', '112362'],
#  ['Newcastle upon Tyne', '268064'],
#  ['Sunderland', '174286'],
#  ['Gateshead', '120046'],
#  ['Middlesbrough', '174700'],
#  ['Manchester', '510746'],
#  ['Wigan', '103608'],
#  ['Stockport', '105878'],
#  ['Bolton', '194189'],
#  ['Salford', '103886'],
#  ['Oldham', '96555'],
#  ['Rochdale', '107926'],
#  ['Warrington', '165456'],
#  ['Blackpool', '147663'],
#  ['Blackburn', '117963'],
#  ['Liverpool', '552267'],
#  ['Birkenhead', '142968'],
#  ['St Helens', '102885'],
#  ['Preston', '97886'],
#  ['Leeds', '474632'],
#  ['Wakefield', '99251'],
#  ['Bradford', '349561'],
#  ['Huddersfield', '162949'],
#  ['Sheffield', '518090'],
#  ['Doncaster', '109805'],
#  ['Rotherham', '109691'],
#  ['York', '152841'],
#  ['Kingston upon Hull', '284321'],
#  ['Nottingham', '289301'],
#  ['Northampton', '215173'],
#  ['Leicester', '443760'],
#  ['Derby', '255394'],
#  ['Lincoln', '100160'],
#  ['Birmingham', '1085810'],
#  ['Coventry', '325949'],
#  ['Wolverhampton', '210319'],
#  ['Solihull', '123187'],
#  ['Stoke-on-Trent', '270726'],
#  ['Worcester', '100153'],
#  ['Sutton Coldfield', '109015'],
#  ['Telford', '142723'],
#  ['Cambridge', '145818'],
#  ['Peterborough', '161707'],
#  ['Ipswich', '144957'],
#  ['Chelmsford', '110507'],
#  ['Watford', '131982'],
#  ['Southend-on-Sea', '175547'],
#  ['Basildon', '107123'],
#  ['Colchester', '119441'],
#  ['Norwich', '186682'],
#  ['Luton', '211228'],
#  ['London', '8250205'],
#  ['Southampton', '253651'],
#  ['Portsmouth', '238137'],
#  ['Basingstoke', '107355'],
#  ['Milton Keynes', '171750'],
#  ['High Wycombe', '120256'],
#  ['Brighton and Hove', '229700'],
#  ['Maidstone', '107627'],
#  ['Oxford', '159994'],
#  ['Reading', '218705'],
#  ['Slough', '155298'],
#  ['Eastbourne', '109185'],
#  ['Gillingham', '104157'],
#  ['Crawley', '106943'],
#  ['Worthing', '109120'],
#  ['Woking', '105367'],
#  ['Bristol', '535907'],
#  ['Plymouth', '234982'],
#  ['Exeter', '113507'],
#  ['Bournemouth', '187503'],
#  ['Poole', '154718'],
#  ['Cheltenham', '116447'],
#  ['Gloucester', '136362'],
#  ['Swindon', '182441'],
#  ['Edinburgh', '459366'],
#  ['Glasgow', '590507'],
#  ['Aberdeen', '195021'],
#  ['Dundee', '147285'],
#  ['Kirkwall', '6330'],
#  ['Lerwick', '6570'],
#  ['Cardiff', '335145'],
#  ['Swansea', '179485'],
#  ['Newport', '128060'],
#  ['Belfast', '280561'],
#  ['Kabul', '2435400'],
#  ['Herat', '335200'],
#  ['Kandahar', '311800'],
#  ['Mazar-i-Sharif', '288700'],
#  ['Hefei', '3310268'],
#  ['Huainan', '1200000'],
#  ['Bengbu', '449245'],
#  ['Wuhu', '425740'],
#  ['Huaibei', '366549'],
#  ['Maanshan', '305421'],
#  ['Anqing', '250718'],
#  ['Tongling', '228017'],
#  ['Fuyang', '179572'],
#  ['Luan', '144248'],
#  ['Chuxian', '125341'],
#  ['Chaoxian', '123676'],
#  ['Xuancheng', '112673'],
#  ['Fuzhou', '2921762'],
#  ['Xiamen', '3531347'],
#  ['Nanping', '195064'],
#  ['Quanzhou', '185154'],
#  ['Zhangzhou', '181424'],
#  ['Sanming', '160691'],
#  ['Longyan', '134481'],
#  ['Yongan', '111762'],
#  ['Lanzhou', '2628426'],
#  ['Tianshui', '244974'],
#  ['Baiyin', '204970'],
#  ['Wuwei', '133101'],
#  ['Yumen', '109234'],
#  ['Guangzhou', '11071424'],
#  ['Shantou', '5329024'],
#  ['Zhanjiang', '400997'],
#  ['Shenzhen', '10358381'],
#  ['Shaoguan', '350043'],
#  ['Chaozhou', '313469'],
#  ['Dongguan', '8220207'],
#  ['Foshan', '7194311'],
#  ['Zhongshan', '3121275'],
#  ['Jiangmen', '230587'],
#  ['Yangjiang', '215196'],
#  ['Zhaoqing', '194784'],
#  ['Maoming', '178683'],
#  ['Zhuhai', '164747'],
#  ['Huizhou', '2344634'],
#  ['Meixian', '132156'],
#  ['Heyuan', '120101'],
#  ['Shanwei', '107847'],
#  ['Guiyang', '3034750'],
#  ['Liupanshui', '363954'],
#  ['Zunyi', '261862'],
#  ['Anshun', '174142'],
#  ['Duyun', '132971'],
#  ['Kaili', '113958'],
#  ['Haikou', '280153'],
#  ['Sanya', '102820'],
#  ...]

# %%
df = pd.DataFrame(final_popu_list)
df.columns = ['city', 'population']
df
# Out:
#               city population
# 0           Tirana     418495
# 1          Shkodër      77075
# 2           Durrës     113249
# 3            Vlorë      79513
# 4          Elbasan      78703
# 5            Korçë      51152
# 6           Kavala      58790
# 7           Athina     664046
# 8         Peiraias     163688
# 9        Peristeri     139981
# 10        Acharnes     106943
# 11           Patra     213984
# 12         Kerkyra     102071
# 13        Ioannina     112486
# 14    Thessaloniki     325182
# 15         Iraklio     173993
# 16          Chania     108642
# 17          Rhodes     115490
# 18           Lamia      75315
# 19        Chalkida     102223
# 20         Larissa     162591
# 21           Volos     144449
# 22          Karyes        233
# 23          Skopje     514967
# 24        Kumanovo     107745
# 25         Beograd    1639121
# 26        Novi Sad     335701
# 27             Niš     257867
# 28       Podgorica     150977
# 29       Prishtine     198214
# ...            ...        ...
# 3020            Bo     149957
# 3021       Kampala    1516210
# 3022       Mbarara     195013
# 3023        Mukono     161996
# 3024        Maseru     227880
# 3025   Antsiranana      59040
# 3026  Antananarivo     710236
# 3027     Antsirabe     126062
# 3028  Fianarantsoa     109260
# 3029       Majunga     106780
# 3030      Tamatave     137782
# 3031       Toliara      80826
# 3032      Lilongwe     674448
# 3033      Blantyre     661256
# 3034         Pemba     138716
# 3035       Xai-Xai     115752
# 3036     Inhambane      65149
# 3037       Chimoio     237497
# 3038  Nacala Porto     206449
# 3039        Matola     671556
# 3040       Nampula     471717
# 3041      Lichinga     142331
# 3042         Beira     431583
# 3043          Tete     155870
# 3044     Quelimane     193343
# 3045        Maputo    1094628
# 3046       Mbabane      57992
# 3047   Saint-Denis     145347
# 3048      São Tomé      49957
# 3049      Victoria      24970
#
# [3050 rows x 2 columns]

# %%
df.population = df.population.astype(int)
df.sort('population', ascending=False).head(10)
# Out:
#            city  population
# 1251   Shanghai    22315474
# 707    Istanbul    13710512
# 1421     Mumbai    12442373
# 443      Moskva    11979529
# 1250    Beijing    11716620
# 2594  São Paulo    11152344
# 1252    Tianjin    11090314
# 974   Guangzhou    11071424
# 1467      Delhi    11034555
# 977    Shenzhen    10358381

# %%
ethnic_group = []

for element in document_tree.iterfind('country'):
    if element.find('population') == None:
        continue
    elif element.find('ethnicgroup') == None:
        continue
    else: 
        for subelement in element.findall('ethnicgroup'):
            ethnic_group.append([subelement.text, float(subelement.attrib['percentage']) * 0.01 * float(element.findall('population')[-1].text)])

# %%
ethnic_group
# Out:
# [['Albanian', 2660131.1],
#  ['Greek', 84004.14],
#  ['Greek', 10059145.98],
#  ['Macedonian', 1322387.7480000001],
#  ['Albanian', 519068.088],
#  ['Turkish', 80331.966],
#  ['Gypsy', 55614.43800000001],
#  ['Serb', 37076.292],
#  ['Serb', 5903032.114],
#  ['Montenegrin', 64085.994000000006],
#  ['Hungarian', 277705.974],
#  ['Roma', 99689.324],
#  ['Bosniak', 128171.98800000001],
#  ['Croat', 78327.326],
#  ['Montenegrin', 266612.47],
#  ['Serb', 198409.28],
#  ['Bosniak', 49602.32],
#  ['Albanian', 31001.45],
#  ['Albanian', 1595162.24],
#  ['Serbian', 86693.6],
#  ['Spanish', 33589.45],
#  ['Andorran', 25777.95],
#  ['Portuguese', 8592.65],
#  ['French', 1562.3],
#  ['African', 3905.75],
#  ['Mediterranean Nordic', 46815916.0],
#  ['Austrian', 7743280.448999999],
#  ['Turkish', 135996.144],
#  ['Slovene', 84997.59],
#  ['Croat', 169995.18],
#  ['Serbs', 169995.18],
#  ['German', 76497.831],
#  ['Czech', 9548241.456],
#  ['Moravian', 390801.91800000006],
#  ['Slovak', 200682.066],
#  ['German', 52811.07],
#  ['Polish', 63373.284],
#  ['Roma', 31686.642],
#  ['Hungarian', 21124.428],
#  ['German', 73401020.925],
#  ['Turkish', 1925272.68],
#  ['Hungarian', 9172430.644000001],
#  ['Roma', 188814.932],
#  ['Serb', 198752.56],
#  ['German', 258378.328],
#  ['Slovak', 79501.024],
#  ['Romanian', 69563.396],
#  ['Italian', 1831.8000000000002],
#  ['Alemannic', 34804.200000000004],
#  ['Slovak', 4625259.852000001],
#  ['Hungarian', 523512.49199999997],
#  ['Roma', 91749.61200000001],
#  ['Czech', 53970.36],
#  ['Ukrainian', 16191.108],
#  ['Ruthenian', 16191.108],
#  ['German', 5397.036],
#  ['Polish', 5397.036],
#  ['Slovene', 1873527.11],
#  ['Croat', 61764.63],
#  ['Serb', 41176.42],
#  ['Bosniak', 20588.21],
#  ['German', 5290760.15],
#  ['French', 1465133.5799999998],
#  ['Italian', 813963.1000000001],
#  ['Romansch', 81396.31],
#  ['Belorussian', 7682081.904],
#  ['Russian', 1078518.888],
#  ['Polish', 368966.988],
#  ['Ukrainian', 227056.608],
#  ['Latvian', 1305309.228],
#  ['Russian', 611932.488],
#  ['Belorussian', 79243.05600000001],
#  ['Ukrainian', 55029.9],
#  ['Polish', 52828.704],
#  ['Lithuanian', 28615.548000000003],
#  ['Lithuanian', 2502620.4],
#  ['Polish', 181737.91],
#  ['Russian', 145986.19],
#  ['Belorussian', 32772.41],
#  ['German', 500939.25700000004],
#  ['Polish', 37608978.063999996],
#  ['Ukrainian', 231202.734],
#  ['Byelorussian', 192668.945],
#  ['Ukrainian', 35502969.586],
#  ['Russian', 7894619.201],
#  ['Belorussian', 273801.822],
#  ['Moldovan', 228168.185],
#  ['Crimean Tatar', 228168.185],
#  ['Bulgarian', 182534.548],
#  ['Hungarian', 136900.911],
#  ['Romanian', 136900.911],
#  ['Polish', 136900.911],
#  ['Jewish', 91267.274],
#  ['Russian', 114646210.93800001],
#  ['Tatar', 5459343.378],
#  ['Ukrainian', 2873338.62],
#  ['Bashkir', 1724003.172],
#  ['Chuvash', 1580336.2410000002],
#  ['Fleming', 6437741.319999999],
#  ['Walloon', 3440861.7399999998],
#  ['Luxembourgish', 331182.243],
#  ['Portuguese', 69805.44900000001],
#  ['French', 23618.385],
#  ['Italian', 22568.678999999996],
#  ['German', 12071.619],
#  ['Dutch', 13592447.067000002],
#  ['Indonesian', 404236.344],
#  ['Turkish', 370549.982],
#  ['Moroccan', 336863.62],
#  ['Surinamese', 336863.62],
#  ['Caribbean', 134745.448],
#  ['Muslim', 1819978.5599999998],
#  ['Bosniak', 1406691.7619999999],
#  ['Croat', 542201.9460000001],
#  ['Croat', 3844388.3519999995],
#  ['Serb', 193077.53999999998],
#  ['Hungarian', 21453.06],
#  ['Muslim', 38615.508],
#  ['Slovene', 21453.06],
#  ['Bulgarian', 5601820.488000001],
#  ['Turkish', 582764.16],
#  ['Roma', 320520.28800000006],
#  ['Macedonian', 182113.80000000002],
#  ['Russian', 14569.104000000001],
#  ['Armenian', 21853.656],
#  ['Romanian', 17928382.131],
#  ['Hungarian', 1328028.306],
#  ['Roma', 503041.025],
#  ['German', 60364.923],
#  ['Ukrainian', 60364.923],
#  ['Russian', 40243.282],
#  ['Turkish', 40243.282],
#  ['Turkish', 63935390.4336],
#  ['Kurdish', 9052597.8648],
#  ['Arabic', 1043657.8992],
#  ['Estonian', 889290.5850000001],
#  ['Russian', 331380.48],
#  ['Ukrainian', 27183.555],
#  ['Belorussian', 15533.460000000001],
#  ['Finn', 10355.64],
#  ['Scandinavian', 48197.0],
#  ['Finn', 5095033.512],
#  ['Swede', 305483.80799999996],
#  ['Russian', 27275.34],
#  ['Estonian', 16365.204],
#  ['Norwegian', 4167301.8750000005],
#  ['Sami', 75769.125],
#  ['Swede', 7931391.19],
#  ['Finn', 477794.65],
#  ['French', 17317.15],
#  ['Monegasque', 7958.520000000001],
#  ['Italian', 7000.55],
#  ['Norman-French', 59807.0],
#  ['Celt', 318452.0],
#  ['Irish', 4010132.2480000006],
#  ['Asian', 59647.276000000005],
#  ['African', 50470.772000000004],
#  ['Norman-French', 97857.0],
#  ['Moldavian/Romanian', 2783561.062],
#  ['Ukrainian', 299001.444],
#  ['Russian', 206453.378],
#  ['Gagauz', 156619.804],
#  ['Bulgarian', 67631.279],
#  ['Norwegian', 1037.0880000000002],
#  ['Russian Ukrainian', 829.296],
#  ['English', 53592326.743999995],
#  ['Scottish', 5513086.244],
#  ['Welsh', 3141177.046],
#  ['Northern Irish', 1859063.9659999998],
#  ['African', 1282113.08],
#  ['Indian', 1153901.772],
#  ['Pakistani', 833373.5020000001],
#  ['Tajik', 6505775.0],
#  ['Pashtun', 9888778.0],
#  ['Uzbek', 1561386.0],
#  ['Hazara', 4944389.0],
#  ['Han Chinese', 1245058800.0],
#  ['Arab', 2254490.07],
#  ['Persian', 38326331.19],
#  ['Baloch', 1502993.3800000001],
#  ['Azerbaijani', 18035920.56],
#  ['Kurd', 5260476.83],
#  ['Lur', 1502993.3800000001],
#  ['Turkmen', 1502993.3800000001],
#  ['Gilaki Mazandarani', 6011973.5200000005],
#  ['Tajik', 6520718.9],
#  ['Uzbek', 1248648.3],
#  ['Russian', 89772.1],
#  ['Kyrgyz', 89772.1],
#  ['Turkmen', 4285695.75],
#  ['Uzbek', 252099.75],
#  ['Russian', 201679.80000000002],
#  ['Uzbek', 22215416.0],
#  ['Russian', 1527309.85],
#  ['Tajik', 1388463.5],
#  ['Kazak', 833078.1],
#  ['Karakalpak', 694231.75],
#  ['Tatar', 416539.05],
#  ['Armenian', 2957260.7830000003],
#  ['Russian', 15134.395],
#  ['Yezidi', 39349.427],
#  ['Georgian', 3757424.4],
#  ['Azeri', 291447.0],
#  ['Russian', 67257.0],
#  ['Azeri', 8476989.0],
#  ['Dagestani', 205843.00000000003],
#  ['Russian', 168417.00000000003],
#  ['Armenian', 140347.5],
#  ['Arab', 123459.6],
#  ['Asian', 160497.48],
#  ['Bahraini', 777795.48],
#  ['Iranian', 98767.68000000001],
#  ['Bengali', 146776916.72],
#  ['Indian', 1028388.4],
#  ['Chinese', 1542582.5999999999],
#  ['Burman', 34965205.6],
#  ['Shan', 4627747.8],
#  ['Karen', 3599359.4000000004],
#  ['Rakhine', 2056776.8],
#  ['Mon', 1028388.4],
#  ['Dravidian', 302713744.25],
#  ['Indo-Aryan', 871815583.4399999],
#  ['Mongol', 36325649.309999995],
#  ['Bhote', 366502.0],
#  ['Nepalese', 256551.40000000002],
#  ['Chinese', 78674.40000000001],
#  ['Malay', 251758.08000000002],
#  ['Malay', 13893173.784],
#  ['Chinese', 6533099.577],
#  ['Indian', 1957173.2909999997],
#  ['Borneo indigenous', 3032240.31],
#  ['Lao Loum', 4429813.760000001],
#  ['Lao Theung', 1433175.04],
#  ['Lao Soung Hmong Yao', 586298.88],
#  ['Vietnamese/Chinese', 65144.32],
#  ['Chinese', 9237432.260000002],
#  ['Thai', 49486244.25],
#  ['Chinese', 143649.31],
#  ['Khmer', 12928437.9],
#  ['Vietnamese', 718246.55],
#  ['Viet/Kinh', 76078375.30000001],
#  ['Tay', 1686685.0999999999],
#  ['Thai', 1597912.2000000002],
#  ['Muong', 1331593.5],
#  ['Khmer', 1331593.5],
#  ['Mong', 1065274.8],
#  ['Nung', 976501.9000000001],
#  ['Kazakh', 10831265.809],
#  ['Russian', 4068161.6429999997],
#  ['Uzbek', 480626.6919999999],
#  ['Ukrainian', 360470.01900000003],
#  ['Uighur', 240313.34599999996],
#  ['Tatar', 223148.10700000002],
#  ['German', 188817.62900000002],
#  ['Kyrgyz', 3749013.4],
#  ['Uzbek', 797170.8],
#  ['Russian', 722075.0],
#  ['Dungan', 63542.600000000006],
#  ['Ukrainian', 57766.0],
#  ['Uighur', 57766.0],
#  ['Chinese', 6717997.2],
#  ['Filipino', 113145.216],
#  ['Indonesian', 91930.48800000001],
#  ['Chinese', 524877.8500000001],
#  ['Portuguese', 16575.09],
#  ['Mongol', 2614196.0650000004],
#  ['Kazak', 137734.25],
#  ['Chinese', 1450.4],
#  ['Malay', 207.20000000000002],
#  ['European', 414.40000000000003],
#  ['Greek', 647113.39],
#  ['Turkish', 151273.25999999998],
#  ['Jewish', 10560.222],
#  ['Palestinian Arab', 1749476.7780000002],
#  ['Jewish', 5669161.152000001],
#  ['Arab', 1706684.6400000001],
#  ['European', 836670.47],
#  ['Eastern Hamitic', 82830376.53],
#  ['Javanese', 113456006.10000001],
#  ['Sundanese', 35297424.120000005],
#  ['Madurese', 18909334.349999998],
#  ['Malay', 18909334.349999998],
#  ['Kurdish', 4999576.8],
#  ['Arab', 24997884.0],
#  ['Assyrian', 1666525.6],
#  ['Armenian', 62490.0],
#  ['Arab', 6124020.0],
#  ['Circassian', 62490.0],
#  ['Arab', 1047053.0000000001],
#  ['Iranian', 119663.2],
#  ['South Asian', 269242.2],
#  ['Kuwaiti', 1346211.0],
#  ['Arab', 24423279.3],
#  ['Afro-Asian', 2713697.7],
#  ['Arab', 18841998.0],
#  ['Armenian', 173643.68],
#  ['Arab', 4124037.4000000004],
#  ['Jewish', 474356.27],
#  ['Palestinian Arab', 2315974.73],
#  ['Japanese', 126534212.00000001],
#  ['South Asian', 4220768.5],
#  ['Emiri', 1603892.03],
#  ['Arab Iranian', 1941553.51],
#  ['Chinese', 1385067.78],
#  ['Malay', 88182648.66000001],
#  ['Indian', 305898.3],
#  ['Pakistani', 305898.3],
#  ['Arab', 679774.0],
#  ['Iranian', 169943.5],
#  ['Indian', 324908.8],
#  ['Chinese', 3878598.8000000007],
#  ['Malay', 756428.2999999999],
#  ['Sinhalese', 14995155.02],
#  ['Tamil', 3647470.1399999997],
#  ['Arab', 1418460.61],
#  ['Vedda', 202637.23],
#  ['Chinese', 3264215.0800000005],
#  ['Taiwanese', 19585290.48],
#  ['Black', 11746.337],
#  ['Mulatto', 599.702],
#  ['White', 482.3690000000001],
#  ['European/Caribbean Amerindian', 81187.20000000001],
#  ['European', 11112.84],
#  ['African', 222256.80000000002],
#  ['Mestizo', 152416.877],
#  ['Creole', 77929.779],
#  ['Maya', 33174.926],
#  ['Garifuna', 19091.231],
#  ['Mestizo', 7536687.5],
#  ['European', 1507337.5],
#  ['Amerindian', 4597379.375],
#  ['Mestizo', 67401922.8],
#  ['Amerindian', 33700961.4],
#  ['European', 10110288.42],
#  ['Black', 34687.98],
#  ['White', 21904.817000000003],
#  ['Mixed', 4111.168],
#  ['Black', 19316.274],
#  ['White', 1621.2700000000002],
#  ['Amerindian', 787.474],
#  ['Mixed', 1250.6940000000002],
#  ['British Isles', 9844325.120000001],
#  ['French', 8086409.92],
#  ['European', 5273745.6],
#  ['Inuit', 703166.08],
#  ['European', 254958101.97759998],
#  ['African', 40973131.696],
#  ['Asian', 14125367.5808],
#  ['Amerindian', 3092913.4432],
#  ['Black', 11138.2],
#  ['White', 11138.2],
#  ['Mixed', 22276.4],
#  ['Mestizo', 3532108.06],
#  ['European', 954623.8],
#  ['African', 143193.57],
#  ['Amerindian', 47731.19],
#  ['Chinese', 47731.19],
#  ['Mestizo', 4189021.0500000003],
#  ['European', 1032077.65],
#  ['African', 546394.0499999999],
#  ['Amerindian', 303552.25],
#  ['Mestizo', 2860882.92],
#  ['European', 340581.30000000005],
#  ['Amerindian', 204348.78],
#  ['European', 7269928.574999999],
#  ['Mestizo', 1340079.0],
#  ['Mulatto', 1340079.0],
#  ['African', 1127899.825],
#  ['Carib Indians', 70739.0],
#  ['Mulatto', 6895055.13],
#  ['European', 1511244.96],
#  ['African', 1038980.91],
#  ['African', 9401580.0],
#  ['Mulatto', 296892.0],
#  ['European', 197928.0],
#  ['Mestizo', 5661378.0],
#  ['European', 566137.7999999999],
#  ['Amerindian', 62904.200000000004],
#  ['Mestizo', 7241391.0],
#  ['Amerindian', 563219.3],
#  ['African', 160919.80000000002],
#  ['European', 80459.90000000001],
#  ['Danish', 7891.800000000001],
#  ['Greenlander', 48478.2],
#  ['African', 103328.0],
#  ['Chinese', 20231.75],
#  ['African', 2058561.029],
#  ['Afro-European', 407395.43299999996],
#  ['Afro-East Indian', 80939.48999999999],
#  ['Afro-Chinese', 32375.796000000002],
#  ['Chinese', 19614.55],
#  ['African-white-Indian', 353061.9],
#  ['Mestizo', 27643836.459999997],
#  ['European', 9532357.4],
#  ['Mulatto', 6672650.180000001],
#  ['African', 1906471.48],
#  ['black-Amerindian', 1429853.6099999999],
#  ['Amerindian', 476617.87],
#  ['White', 2988082.7780000004],
#  ['Black', 298063.12],
#  ['Amerindian', 14903.156],
#  ['Asian', 14903.156],
#  ['African', 52352.0],
#  ['African', 149532.285],
#  ['East Indian', 5299.04],
#  ['Basques Bretons', 6312.0],
#  ['Chinese', 13280.19],
#  ['East Indian', 531207.6],
#  ['African', 28312.2],
#  ['Caucasian', 1110.38],
#  ['Tongan', 2220.76],
#  ['Samoan', 49411.91],
#  ['European', 21284458.52],
#  ['Asian', 1619469.6700000002],
#  ['Polynesian', 16637.39],
#  ['Indian', 395857.14],
#  ['Fijian', 421673.91],
#  ['French', 26827.0],
#  ['Chinese', 32192.399999999998],
#  ['Polynesian', 209250.6],
#  ['Chamorro', 59121.818],
#  ['Filipino', 41911.154],
#  ['Micronesian', 103058.0],
#  ['Micronesian', 53158.0],
#  ['Polynesian', 102843.0],
#  ['Chinese', 802.0],
#  ['European', 802.0],
#  ['Nauruan', 5814.5],
#  ['Pacific Islander', 2606.5],
#  ['Vietnamese', 3438.1199999999994],
#  ['European', 83742.78000000001],
#  ['Melanesian', 108300.78],
#  ['Wallisian', 22102.2],
#  ['Indonesian', 6139.5],
#  ['European', 2409483.264],
#  ['Asian', 339363.84],
#  ['Maori', 313911.552],
#  ['Pacific Islander', 195134.20799999998],
#  ['Polynesian', 1611.0],
#  ['Asian', 30336.128999999997],
#  ['Pacific Islander', 19559.529],
#  ['Caucasian', 969.8940000000001],
#  ['Bounty', 66.0],
#  ['Chinese', 1579.3410000000001],
#  ['European', 4211.576],
#  ['Polynesian', 21057.88],
#  ['Micronesian', 7896.705],
#  ['Melanesian', 489595.71],
#  ['Polynesian', 9433.92],
#  ['Polynesian', 1313.8500000000001],
#  ['French', 9451.960000000001],
#  ['Melanesian', 222121.06000000003],
#  ['Polynesian', 12197.0],
#  ['Europeans', 751.28],
#  ['Samoan', 173921.31999999998],
#  ['Euronesians', 13147.400000000001],
#  ['European', 41389415.0],
#  ['Quechua', 3008178.6],
#  ['Mestizo', 3008178.6],
#  ['Aymara', 2506815.5],
#  ['European', 1504089.3],
#  ['European', 108886717.794],
#  ['Mulatto', 78065896.37],
#  ['African', 12571650.844],
#  ['Amerindian', 490257.87],
#  ['European', 15524832.55],
#  ['Mestizo', 6338999.45],
#  ['European', 2891956.32],
#  ['Mestizo', 262905.12],
#  ['African', 131452.56],
#  ['Amerindian', 13561143.75],
#  ['Mestizo', 11150273.75],
#  ['European', 4520381.25],
#  ['Amerindian', 28505.879999999997],
#  ['East Indian', 325329.54],
#  ['African', 225860.968],
#  ['Amerindian', 68057.444],
#  ['Hindustani', 200406.06],
#  ['Creole', 167907.78],
#  ['Javanese', 82870.614],
#  ['African', 54163.8],
#  ['Chinese', 10832.76],
#  ['Amerindian', 10832.76],
#  ['Europeans', 5416.38],
#  ['Mestizo', 9414274.35],
#  ['Amerindian', 3620874.75],
#  ['European', 1013844.93],
#  ['African', 434504.97],
#  ['Christian', 1969.632],
#  ['None', 923.265],
#  ['European', 370628.2],
#  ['Arab-Berber', 36692191.8],
#  ['Berber Arab', 5859393.64],
#  ['Mande', 6992980.5],
#  ['Peuhl', 2377613.37],
#  ['Voltaic', 1678315.3199999998],
#  ['Songhai', 839157.6599999999],
#  ['Tuareg', 1398596.1],
#  ['Maur', 1061210.4],
#  ['Black Maur', 1414947.2000000002],
#  ['Jewish', 65803.244],
#  ['Arab-Berber', 32605507.402],
#  ['Fula', 1456790.0950000002],
#  ['Hausa', 9597675.920000002],
#  ['Djerma', 3770515.54],
#  ['Tuareg', 1371096.56],
#  ['Beri Beri', 736964.401],
#  ['Gourmantche', 205664.484],
#  ['Jewish', 109827.54000000001],
#  ['European', 109827.54000000001],
#  ['Arab-Berber', 10763098.92],
#  ['European', 243833.01],
#  ['Ovimbundu', 9021821.37],
#  ['Kimbundu', 6095825.25],
#  ['Bakongo', 3169829.13],
#  ['Mangbetu-Azande', 27986022.45],
#  ['European', 143511.58800000002],
#  ['African', 12876903.396000002],
#  ['African', 9884045.16],
#  ['Mossi', 4157471.04],
#  ['African', 162651570.84],
#  ['African', 6129243.45],
#  ['European Syrian-Lebanese', 61911.55],
#  ['Batswana', 1936316.6],
#  ['Kgalagadi', 81529.12],
#  ['Indian', 1346034.56],
#  ['Colored', 4452268.159999999],
#  ['Asian', 130612.39],
#  ['African', 12800014.22],
#  ['Malinke', 2493846.41],
#  ['Baoule', 5214406.13],
#  ['Bete', 4080839.58],
#  ['Senoufou', 3400699.65],
#  ['European', 49317.646],
#  ['African', 24609505.354],
#  ['Hutu', 8412778.4],
#  ['Tutsi', 1998034.87],
#  ['Twa', 105159.73],
#  ['Bantu', 42682476.85],
#  ['African', 2522793.0],
#  ['Fulani', 1940610.0],
#  ['Cameroon Highlanders', 6015891.0],
#  ['Equatorial Bantu', 3687159.0],
#  ['Kirdi', 2134671.0],
#  ['Northwestern Bantu', 1552488.0],
#  ['Eastern Nigritic', 1358427.0000000002],
#  ['Baya', 1478973.1400000001],
#  ['Banda', 1174478.6700000002],
#  ['Sara', 434992.10000000003],
#  ['Mandjia', 913483.4099999999],
#  ['Mboum', 173996.84],
#  ['MBaka', 173996.84],
#  ['European', 4918.75],
#  ['African', 137725.0],
#  ['Creole', 349231.25],
#  ['Arab', 24956401.400000002],
#  ['Beja', 2139120.12],
#  ['Malinke', 3188691.6],
#  ['Peuhl', 4251588.8],
#  ['Soussou', 2125794.4],
#  ['African', 3760090.5000000005],
#  ['Americo-Liberians', 197899.5],
#  ['Italian', 41701.8],
#  ['Afar', 291912.60000000003],
#  ['Somali', 500421.6],
#  ['Tigrinya', 3157637.45],
#  ['Tigre', 1722347.7],
#  ['Saho', 229646.36000000002],
#  ['Kunama', 114823.18000000001],
#  ['Rashaida', 114823.18000000001],
#  ['Bilen', 114823.18000000001],
#  ['Oromo', 29090740.515],
#  ['Amhara', 22682345.503000002],
#  ['Somali', 5227901.194],
#  ['Tigraway', 5143580.2069999995],
#  ['Sidama', 3372839.48],
#  ['Gurage', 2108024.6750000003],
#  ['Welaita', 1939382.701],
#  ['Hadiya', 1433456.779],
#  ['Afar', 1433456.779],
#  ['Somali', 8190747.05],
#  ['Arab', 409091.94],
#  ['Kikuyu', 9000022.68],
#  ['Luhya', 5727287.16],
#  ['Luo', 5318195.22],
#  ['Kalenjin', 4909103.28],
#  ['Kamba', 4500011.34],
#  ['Kisii', 2454551.64],
#  ['Meru', 2454551.64],
#  ['African', 1863625.5],
#  ['Fulani', 2296481.5500000003],
#  ['Wolof', 4863137.399999999],
#  ['Diola', 1215784.3499999999],
#  ['Mandingo', 1215784.3499999999],
#  ['Serer', 2296481.5500000003],
#  ['Toucouleur', 1215784.3499999999],
#  ['European Lebanese', 135087.15],
#  ['European', 15866.24],
#  ['African', 1570757.76],
#  ['Asian', 57519.76],
#  ['African', 5694456.24],
#  ['Rwanda', 2091408.78],
#  ['Arab', 348568.13],
#  ['Baganda', 5925658.21],
#  ['Karamojong', 4182817.56],
#  ['Basogo', 2788545.04],
#  ['Iteso', 2788545.04],
#  ['Langi', 2091408.78],
#  ['Bagisu', 1742840.6500000001],
#  ['Acholi', 1394272.52],
#  ['Lugbara', 1394272.52],
#  ['Bunyoro', 1045704.39],
#  ['Batobo', 1045704.39],
#  ['Sotho', 2002894.237],
#  ['European', 14220.428999999998],
#  ['Indian', 18960.572],
#  ['Euro-African', 47401.43],
#  ['Creole', 334014.57],
#  ['Indo-Mauritian', 841221.88],
#  ['Sino-Mauritian', 37112.729999999996],
#  ['Franco-Mauritian', 24741.82],
#  ['European', 35794.439999999995],
#  ['African', 1157353.56],
#  ['African descent', 2831.5],
#  ['White', 1415.75],
#  ['Chinese', 1415.75],
#  ['European', 187356.0],
#  ['Seychellois', 90945.0]]

# %%
import pandas as pd
df = pd.DataFrame(ethnic_group)
df.columns = ['ethnic', 'population']
df
# Out:
#                    ethnic    population
# 0                Albanian   2660131.100
# 1                   Greek     84004.140
# 2                   Greek  10059145.980
# 3              Macedonian   1322387.748
# 4                Albanian    519068.088
# 5                 Turkish     80331.966
# 6                   Gypsy     55614.438
# 7                    Serb     37076.292
# 8                    Serb   5903032.114
# 9             Montenegrin     64085.994
# 10              Hungarian    277705.974
# 11                   Roma     99689.324
# 12                Bosniak    128171.988
# 13                  Croat     78327.326
# 14            Montenegrin    266612.470
# 15                   Serb    198409.280
# 16                Bosniak     49602.320
# 17               Albanian     31001.450
# 18               Albanian   1595162.240
# 19                Serbian     86693.600
# 20                Spanish     33589.450
# 21               Andorran     25777.950
# 22             Portuguese      8592.650
# 23                 French      1562.300
# 24                African      3905.750
# 25   Mediterranean Nordic  46815916.000
# 26               Austrian   7743280.449
# 27                Turkish    135996.144
# 28                Slovene     84997.590
# 29                  Croat    169995.180
# ..                    ...           ...
# 598               African   1570757.760
# 599                 Asian     57519.760
# 600               African   5694456.240
# 601                Rwanda   2091408.780
# 602                  Arab    348568.130
# 603               Baganda   5925658.210
# 604            Karamojong   4182817.560
# 605                Basogo   2788545.040
# 606                 Iteso   2788545.040
# 607                 Langi   2091408.780
# 608                Bagisu   1742840.650
# 609                Acholi   1394272.520
# 610               Lugbara   1394272.520
# 611               Bunyoro   1045704.390
# 612                Batobo   1045704.390
# 613                 Sotho   2002894.237
# 614              European     14220.429
# 615                Indian     18960.572
# 616          Euro-African     47401.430
# 617                Creole    334014.570
# 618        Indo-Mauritian    841221.880
# 619        Sino-Mauritian     37112.730
# 620      Franco-Mauritian     24741.820
# 621              European     35794.440
# 622               African   1157353.560
# 623       African descent      2831.500
# 624                 White      1415.750
# 625               Chinese      1415.750
# 626              European    187356.000
# 627           Seychellois     90945.000
#
# [628 rows x 2 columns]

# %%
df = df.groupby('ethnic', as_index=True).sum()
df.population = df.population.astype(int)
df.sort('population', ascending=False).head(10)
# Out:
#              population
# ethnic
# Han Chinese  1245058800
# Indo-Aryan    871815583
# European      494872219
# African       318325120
# Dravidian     302713744
# Mestizo       157734354
# Bengali       146776916
# Russian       131856996
# Japanese      126534212
# Malay         121993550

# %%
length = 0
name = ''
country = ''

for element in document_tree.iterfind('river'):
    if element.find('length') == None:
        continue
    elif float(element.find('length').text) > length:
        length = float(element.find('length').text)
        name = element.find('name').text
        country = element.attrib['country']
        
print "The name and country of the longest river are %s and %s" % (name, country)
# Out:
# The name and country of the longest river are Amazonas and CO BR PE

# %%
area = 0
name = ''
country = ''

for element in document_tree.iterfind('lake'):
    if element.find('area') == None:
        continue
    elif float(element.find('area').text) > area:
        area = float(element.find('area').text)
        name = element.find('name').text
        country = element.attrib['country']

print "The name and country of the largest lake are %s and %s" % (name, country)
# Out:
# The name and country of the largest lake are Caspian Sea and R AZ KAZ IR TM

# %%
elevation = 0
name = ''
country = ''

ele_list = []

for element in document_tree.iterfind('airport'):
    if element.find('elevation') == None:
        continue
    else:
        ele_list.append([element.find('name').text, element.attrib['country'], element.find('elevation').text])

# %%
df = pd.DataFrame(ele_list)
df.columns = ['name', 'country', 'elevation']
df.elevation = df.elevation.astype(float)
df = df.dropna()
df = df.sort('elevation', ascending=False)
df
# Out:
#                                                    name country  elevation
# 80                                         El Alto Intl     BOL       4063
# 219                                       Lhasa-Gonggar      CN       4005
# 241                                        Yushu Batang      CN       3963
# 813                                             Juliaca      PE       3827
# 815              Teniente Alejandro Velasco Astete Intl      PE       3311
# 82                             Juana Azurduy De Padilla     BOL       2905
# 334                                 Mariscal Sucre Intl      EC       2813
# 805                 Coronel Fap Alfredo Mendivil Duarte      PE       2719
# 807   Mayor General FAP Armando Revoredo Iglesias Ai...      PE       2677
# 692                 Licenciado Adolfo Lopez Mateos Intl     MEX       2581
# 812                                    Rodriguez Ballon      PE       2563
# 279                                       Eldorado Intl      CO       2549
# 85                                     Jorge Wilsterman     BOL       2549
# 335                                      Mariscal Lamar      EC       2532
# 345                                         Asmara Intl      ER       2336
# 349                                           Bole Intl     ETH       2334
# 688                                Hermanos Serdan Intl     MEX       2244
# 78                                                 Paro     BHT       2235
# 703                       Licenciado Benito Juarez Intl     MEX       2230
# 1306                                         Sanaa Intl      YE       2200
# 689                        General Leobardo C Ruiz Intl     MEX       2177
# 235                            Xining Caojiabao Airport      CN       2170
# 631                                        Eldoret Intl     EAK       2116
# 283                                            La Nubia      CO       2095
# 347                                              Gondar     ETH       1994
# 199                                     Lanzhou Airport      CN       1948
# 1268                                      Santa Fe Muni     USA       1935
# 691                          Queretaro Intercontinental     MEX       1920
# 206                                             Wujiaba      CN       1895
# 1184                      City Of Colorado Springs Muni     USA       1886
# ...                                                 ...     ...        ...
# 669                               Marshall Islands Intl      MH          2
# 1300                       Cat Bi International Airport      VN          2
# 594                                             Niigata       J          2
# 971                                         Gimhae Intl     ROK          2
# 825                                            Pagadian      RP          2
# 1168                                         Miami Intl     USA          2
# 1309                                          Aden Intl      YE          2
# 585                                        Saga Airport       J          2
# 566                                     Venezia Tessera       I          2
# 1296                                           Rach Gia      VN          2
# 315                                             Larnaca      CY          2
# 666                                           Male Intl      MV          2
# 166                                  Gerrard Smith Intl    CAYM          2
# 459                                              Cochin     IND          2
# 1061                                  Suvarnabhumi Intl     THA          2
# 429                           Ioannis Kapodistrias Intl      GR          2
# 66                                         Bahrain Intl     BRN          2
# 165                                   Owen Roberts Intl    CAYM          2
# 392                                 Faa'a International    FPOL          2
# 1142                                      Barra Airport      GB          2
# 555                                                Pisa       I          2
# 164                              Edward Bodden Airfield    CAYM          1
# 752                                             Dunedin      NZ          1
# 286                                        Rafael Nunez      CO          1
# 1155                   Louis Armstrong New Orleans Intl     USA          1
# 341                                     Alexandria Intl      ET         -2
# 745                                            Schiphol      NL         -3
# 742                                           Rotterdam      NL         -5
# 921                                           Astrakhan       R        -20
# 614                                              Atyrau     KAZ        -22
#
# [1289 rows x 3 columns]

# %%
print "The name and country of the airport at hight elevation are %s and %s" % (df.iloc[0][0], df.iloc[0][1])
# Out:
# The name and country of the airport at hight elevation are El Alto Intl and BOL
